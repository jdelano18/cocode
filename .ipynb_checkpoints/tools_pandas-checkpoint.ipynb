# %% [markdown]
# ---
# title: "Create A Series Object From a List"
# description: "A Series object is 1D array, similar to a column in a spreadsheet (with a column name and row labels). Series objects in pandas behave much like one-dimensional NumPy ndarrays and you can often pass them as parameters to NumPy ufuncs."
# tags: Pandas, Numpy, Lists
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# create a Series from a list
s = pd.Series([2, -1, 3, 5])
s
# Out:
# 0    2
# 1   -1
# 2    3
# 3    5
# dtype: int64

# %% [markdown]
# # Example&

# %% [markdown]
# ## Similar to a 1D `ndarray`

# %% [markdown]
# `Series` objects behave much like one-dimensional NumPy `ndarray`s, and you can often pass them as parameters to NumPy functions:

# %%
import numpy as np
np.sin(s)
# Out:
# 0    0.909297
# 1   -0.841471
# 2    0.141120
# 3   -0.958924
# dtype: float64

# %% [markdown]
# Arithmetic operations on `Series` are also possible, and they apply *elementwise*, just like for `ndarray`s:

# %%
s + [1000,2000,3000,4000]
# Out:
# 0    1002
# 1    1999
# 2    3003
# 3    4005
# dtype: int64

# %% [markdown]
# Similar to NumPy, if you add a single number to a `Series`, that number is added to all items in the `Series`. This is called *broadcasting*:

# %%
s + 1000
# Out:
# 0    1002
# 1     999
# 2    1003
# 3    1005
# dtype: int64

# %% [markdown]
# The same is true for all binary operations such as `*` or `/`, and even conditional operations:

# %%
s < 0
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %% [markdown]
# ---
# title: "Index Labels For A Series"
# description: "Each item in a pandas Series object has a unique identifier called the index label. By default, it is the rank of the item in the Series (starting at 0) but you can also set the index labels manually."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
s = pd.Series(values, index = ["label_1", "label_2", "label_import pandas as pd3","..."])

# %% [markdown]
# # Example&

# %%
s2 = pd.Series([68, 83, 112, 68], index=["alice", "bob", "charles", "darwin"])
s2
# Out:
# alice       68
# bob         83
# charles    112
# darwin      68
# dtype: int64

# %% [markdown]
# # Learn More&

# %% [markdown]
# To make it clear when you are accessing by label or by integer location, it is recommended to always use the `loc` attribute when accessing by label, and the `iloc` attribute when accessing by integer location. Check out the bricks on these attributes to learn more!

# %% [markdown]
# ---
# title: "Locate A Value By Label (loc) In A Series"
# description: "Access any element by its label in a pandas Series using the loc attribute."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# locate value at label 'my_label'
s.loc['my_label']

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create an Example Series

# %%
tiger = pd.Series([5,3,3,4], index = ['the_masters', 'us_open', 'the_open', 'pga_championship'])
tiger
# Out:
# the_masters         5
# us_open             3
# the_open            3
# pga_championship    4
# dtype: int64

# %% [markdown]
# ## Locate Value at Label 'the_masters'

# %%
tiger.loc['the_masters']
# Out:
# 5

# %% [markdown]
# ---
# title: "Locate A Value By Index (iloc) In A Series"
# description: "Access any element by its label in a pandas Series using the loc attribute."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# Locate value at 1 index in Series s
s.iloc[index]

# %%
# Locate values in an index slice
s.iloc[lower : upper]

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create an Example Series

# %%
tiger = pd.Series([5,3,3,4], index = ['the_masters', 'us_open', 'the_open', 'pga_championship'])
tiger
# Out:
# the_masters         5
# us_open             3
# the_open            3
# pga_championship    4
# dtype: int64

# %% [markdown]
# ## Locate Value at 2nd index

# %%
tiger.iloc[1]
# Out:
# 3

# %% [markdown]
# ## Slicing a `Series` also slices the index labels:

# %%
tiger.iloc[2:4]
# Out:
# the_open            3
# pga_championship    4
# dtype: int64

# %% [markdown]
# # Example&

# %% [markdown]
# ## Be Careful: Slicing a Series can lead to unexpected results when using default labels!

# %%
surprise = pd.Series([1000, 1001, 1002, 1003])
surprise
# Out:
# 0    1000
# 1    1001
# 2    1002
# 3    1003
# dtype: int64

# %%
surprise_slice = surprise[2:]
surprise_slice
# Out:
# 2    1002
# 3    1003
# dtype: int64

# %% [markdown]
# Oh look! The first element has index label `2`. The element with index label `0` is absent from the slice:

# %%
try:
    surprise_slice[0]
except KeyError as e:
    print("Key error:", e)
# Out:
# Key error: 0

# %% [markdown]
# But remember that you can access elements by integer location using the `iloc` attribute.

# %%
surprise_slice.iloc[0]
# Out:
# 1002

# %% [markdown]
# ---
# title: "Create A Series Object From A Dictionary"
# description: "A Series object is 1D array, similar to a column in a spreadsheet (with a column name and row labels). Creating a Series object from a dictionary will make the keys the index labels."
# tags: Pandas, Dictionaries
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# my_dictionary's keys will be labels and values will be values
s = pd.Series(my_dictionary)

# %% [markdown]
# # Example&

# %%
population = {"NYC": 8550000, "LA": 4000000, "CHI": 3000000, "HOU": 2500000}
s = pd.Series(population)
s
# Out:
# NYC    8550000
# LA     4000000
# CHI    3000000
# HOU    2500000
# dtype: int64

# %% [markdown]
# You can control which elements you want to include in the `Series` and in what order by explicitly specifying the desired `index`:

# %%
s2 = pd.Series(population, index = ["LA", "CHI"])
s2
# Out:
# LA     4000000
# CHI    3000000
# dtype: int64

# %% [markdown]
# ---
# title: "Create A Series Object With A Scalar"
# description: "Initialize a Series object using a scalar and a list of index labels such that all rows have the same value."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# all rows will have the scalar as their value
s = pd.Series(scalar, list_of_index_labels)

# %% [markdown]
# # Example&

# %%
meaning = pd.Series(42, ["life", "universe", "everything"])
meaning
# Out:
# life          42
# universe      42
# everything    42
# dtype: int64

# %% [markdown]
# ---
# title: "Add a Name to a Series"
# description: "Adding a name to a pandas Series object."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# add name 'my_series' to s
s = pd.Series(values, name = "my_series")

# %% [markdown]
# # Example&

# %%
s = pd.Series([100, 38], index=["tim", "jimmy"], name="quality of hair")
s
# Out:
# tim      100
# jimmy     38
# Name: quality of hair, dtype: int64

# %% [markdown]
# ---
# title: "Create A DataFrame from a Dictionary of Series."
# description: "A DataFrame object represents a spreadsheet, with cell values, column names and row index labels. Initialize a DataFrame object from a dictionary of Series."
# tags: Pandas, Dictionaries
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# the values of my_dictionary become the column names
# the index labels are row names and values of the Series are entries
df = pd.DataFrame(my_dictionary)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create a Dictionary of Series

# %%
people_dict = {
    "weight": pd.Series([68, 83, 112], index=["alice", "bob", "charles"]),
    "birthyear": pd.Series([1984, 1985, 1992], index=["bob", "alice", "charles"], name="year"),
    "children": pd.Series([0, 3], index=["charles", "bob"]),
    "hobby": pd.Series(["Biking", "Dancing"], index=["alice", "bob"]),
}

# %% [markdown]
# ## Create the DataFrame

# %%
people = pd.DataFrame(people_dict)
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# A few things to note:
# * the `Series` were automatically aligned based on their index,
# * missing values are represented as `NaN`,
# * `Series` names are ignored (the name `"year"` was dropped),
# * `DataFrame`s are displayed nicely in Jupyter notebooks, woohoo!

# %% [markdown]
# ## You can access columns pretty much as you would expect

# %% [markdown]
# They are returned as `Series` objects:

# %%
people["birthyear"]
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %% [markdown]
# You can also get multiple columns at once:

# %%
people[["birthyear", "hobby"]]
# Out:
#          birthyear    hobby
# alice         1985   Biking
# bob           1984  Dancing
# charles       1992      NaN

# %% [markdown]
# # Example&

# %% [markdown]
# If you pass a list of columns and/or index row labels to the `DataFrame` constructor, it will guarantee that these columns and/or rows will exist, in that order, and no other column/row will exist. For example:

# %%
d2 = pd.DataFrame(
        people_dict,
        columns=["birthyear", "weight", "height"],
        index=["bob", "alice", "eugene"]
     )
d2
# Out:
#         birthyear  weight height
# bob        1984.0    83.0    NaN
# alice      1985.0    68.0    NaN
# eugene        NaN     NaN    NaN

# %% [markdown]
# ---
# title: "Create A DataFrame from a List of Lists."
# description: "A DataFrame object represents a spreadsheet, with cell values, column names and row index labels. Initialize a DataFrame object from a list of lists."
# tags: Pandas, Lists
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd
list_of_lists = [ [], [], ... ]

# %%
df = pd.DataFrame(list_of_lists)

# %%
# add column names and/or index labels
df = pd.DataFrame(
        list_of_lists,
        columns = ["name", "your", "columns", "here"]
        index = ["and/or", "name", "your", "index_labels"]
)

# %% [markdown]
# # Exmaple&

# %% [markdown]
# ## Create a list of lists that is our data

# %%
values = [
            [1985, 1, "Biking", 68],
            [1984, 3, "Dancing", 83],
            [1992, 0, "Skiing", 112]
         ]

# %% [markdown]
# ## Create DataFrame from `values` with column names and index labels

# %%
d3 = pd.DataFrame(
        values,
        columns=["birthyear", "children", "hobby", "weight"],
        index=["alice", "bob", "charles"]
     )
d3
# Out:
#          birthyear  children    hobby  weight
# alice         1985         1   Biking      68
# bob           1984         3  Dancing      83
# charles       1992         0   Skiing     112

# %% [markdown]
# ---
# title: "Create A DataFrame from a Dictionary"
# description: "A DataFrame object represents a spreadsheet, with cell values, column names and row index labels. Initialize a DataFrame object from a list of lists. Initialize a DataFrame from a dictionary"
# tags: Pandas, Dictionaries
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %% [markdown]
# ## By default, the keys become the columns

# %%
pd.DataFrame.from_dict(data)

# %% [markdown]
# ## Specify `orient = 'index'` to use keys as the rows

# %%
pd.DataFrame.from_dict(data, orient = 'index')
# when using 'index' orientation, you can rename columns
pd.DataFrame.from_dict(data, 
                       orient = 'index',
                       columns = ['name_1', 'name_2', '...'])

# %% [markdown]
# # Example&

# %% [markdown]
# # Keys as columns

# %% [markdown]
# ## With index labels

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Without index labels

# %%
data = {"model" : ['s', '3', 'x', 'y'], "seats" : [2,4,6,8], "price" : [100,200,300,400]}
teslas = pd.DataFrame.from_dict(data)
teslas# Example&
# Out:
#   model  seats  price
# 0     s      2    100
# 1     3      4    200
# 2     x      6    300
# 3     y      8    400

# %% [markdown]
# # Example&

# %% [markdown]
# ## `orient = 'index' `

# %%
data = {2018: [100, 200, 250, 300], 2019 : [115, 200, 230, 370]}
money = pd.DataFrame.from_dict(data, orient = 'index')
money
# Out:
#         0    1    2    3
# 2018  100  200  250  300
# 2019  115  200  230  370

# %%
money = pd.DataFrame.from_dict(data, 
                               orient = 'index',
                               columns = ['food', 'internet', 'books', 'rent'])
money
# Out:
#       food  internet  books  rent
# 2018   100       200    250   300
# 2019   115       200    230   370

# %% [markdown]
# ---
# title: "Multi-Index DataFrame FINISH LATER"
# description: "A MultiIndex object is a way to create a hierarchical structure of columns and/or rows. You can think of a MultiIndex as an list of unique tuples.
#
# Use multi-indexing to create a hierarchy of dimensions for your data. If all columns are tuples of the same size, then they are understood as a multi-index. The same goes for row index labels."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html

# %% [markdown]
# # Example&

# %% [markdown]
# # Example&

# %% [markdown]
# If all columns are tuples of the same size, then they are understood as a multi-index. The same goes for row index labels. For example:

# %%
df = pd.DataFrame(
  {
    ("public", "birthyear"):
        {("Paris","alice"):1985, ("Paris","bob"): 1984, ("London","charles"): 1992},
    ("public", "hobby"):
        {("Paris","alice"):"Biking", ("Paris","bob"): "Dancing"},
    ("private", "weight"):
        {("Paris","alice"):68, ("Paris","bob"): 83, ("London","charles"): 112},
    ("private", "children"):
        {("Paris", "alice"):np.nan, ("Paris","bob"): 3, ("London","charles"): 0}
  }
)
df
# Out:
#                 private           public
#                children weight birthyear    hobby
# London charles      0.0    112      1992      NaN
# Paris  alice        NaN     68      1985   Biking
#        bob          3.0     83      1984  Dancing

# %% [markdown]
# You can now get a `DataFrame` containing all the `"public"` columns very simply:

# %%
df["public"]
# Out:
#                 birthyear    hobby
# London charles       1992      NaN
# Paris  alice         1985   Biking
#        bob           1984  Dancing

# %%
df["public", "hobby"]  # Same result as d5["public"]["hobby"]
# Out:
# London  charles        NaN
# Paris   alice       Biking
#         bob        Dancing
# Name: (public, hobby), dtype: object

# %% [markdown]
# ## Dropping a level
# Let's look at `d5` again:

# %%
d5
# Out:
#                 private           public
#                children weight birthyear    hobby
# London charles      0.0    112      1992      NaN
# Paris  alice        NaN     68      1985   Biking
#        bob          3.0     83      1984  Dancing

# %% [markdown]
# There are two levels of columns, and two levels of indices. We can drop a column level by calling `droplevel()` (the same goes for indices):

# %%
d5.columns = d5.columns.droplevel(level = 0)
d5
# Out:
#                 children  weight  birthyear    hobby
# London charles       0.0     112       1992      NaN
# Paris  alice         NaN      68       1985   Biking
#        bob           3.0      83       1984  Dancing

# %% [markdown]
# ## Transposing
# You can swap columns and indices using the `T` attribute:

# %%
d6 = d5.T
d6
# Out:
#            London   Paris
#           charles   alice      bob
# children        0     NaN        3
# weight        112      68       83
# birthyear    1992    1985     1984
# hobby         NaN  Biking  Dancing

# %% [markdown]
# ## Stacking and unstacking levels
# Calling the `stack()` method will push the lowest column level after the lowest index:

# %%
d7 = d6.stack()
d7
# Out:
#                   London    Paris
# children  bob        NaN        3
#           charles      0      NaN
# weight    alice      NaN       68
#           bob        NaN       83
#           charles    112      NaN
# birthyear alice      NaN     1985
#           bob        NaN     1984
#           charles   1992      NaN
# hobby     alice      NaN   Biking
#           bob        NaN  Dancing

# %% [markdown]
# Note that many `NaN` values appeared. This makes sense because many new combinations did not exist before (eg. there was no `bob` in `London`).
#
# Calling `unstack()` will do the reverse, once again creating many `NaN` values.

# %%
d8 = d7.unstack()
d8
# Out:
#           London                Paris
#            alice  bob charles   alice      bob charles
# children    None  NaN       0    None        3     NaN
# weight       NaN  NaN     112      68       83     NaN
# birthyear    NaN  NaN    1992    1985     1984     NaN
# hobby        NaN  NaN    None  Biking  Dancing    None

# %% [markdown]
# If we call `unstack` again, we end up with a `Series` object:

# %%
d9 = d8.unstack()
d9
# Out:
# London  alice    children        None
#                  weight           NaN
#                  birthyear        NaN
#                  hobby            NaN
#         bob      children         NaN
#                  weight           NaN
#                  birthyear        NaN
#                  hobby            NaN
#         charles  children           0
#                  weight           112
#                  birthyear       1992
#                  hobby           None
# Paris   alice    children        None
#                  weight            68
#                  birthyear       1985
#                  hobby         Biking
#         bob      children           3
#                  weight            83
#                  birthyear       1984
#                  hobby        Dancing
#         charles  children         NaN
#                  weight           NaN
#                  birthyear        NaN
#                  hobby           None
# dtype: object

# %% [markdown]
# The `stack()` and `unstack()` methods let you select the `level` to stack/unstack. You can even stack/unstack multiple levels at once:

# %%
d10 = d9.unstack(level = (0,1))
d10
# Out:
#           London                Paris
#            alice  bob charles   alice      bob charles
# children    None  NaN       0    None        3     NaN
# weight       NaN  NaN     112      68       83     NaN
# birthyear    NaN  NaN    1992    1985     1984     NaN
# hobby        NaN  NaN    None  Biking  Dancing    None

# %% [markdown]
# ## Most methods return modified copies
# As you may have noticed, the `stack()` and `unstack()` methods do not modify the object they apply to. Instead, they work on a copy and return that copy. This is true of most methods in pandas.

# %% [markdown]
# ---
# title: "Access Rows of a DataFrame By Index Label (loc)"
# description: "The loc attribute of a pandas DataFrame lets you access rows by the index label. The result is a Series object with the DataFrame's column names mapped to the row index labels."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# single label for a row => Series
df.loc['row_label']

# %%
# list of labels for many rows => DataFrame
df.loc[['row_1', 'row_2', '...']]

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Get one row

# %%
people.loc['alice']
# Out:
# weight           68
# birthyear      1985
# children        NaN
# hobby        Biking
# Name: alice, dtype: object

# %% [markdown]
# ## Get multiple rows

# %%
people.loc[['bob', 'charles']]
# Out:
#          weight  birthyear  children    hobby
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ---
# title: "Access Rows of a DataFrame By Integer Location (iloc)"
# description: "The iloc attribute of a pandas DataFrame lets you access rows by the integer location. The result is a Series object with the DataFrame's column names mapped to the row index labels. You can also get a dataframe from the iloc of multiple rows with slices."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# single row from its index number => Series
df.iloc[index]

# %%
# slice or list of indices for many rows => DataFrame
df.iloc[start : end]

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Get one row

# %%
people.iloc[0]
# Out:
# weight           68
# birthyear      1985
# children        NaN
# hobby        Biking
# Name: alice, dtype: object

# %% [markdown]
# ## Get multiple rows

# %%
people.iloc[1:3]
# Out:
#          weight  birthyear  children    hobby
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ---
# title: "Filter Rows of DataFrame with a Boolean Expression"
# description: "You can pass a boolean array to get the matching rows or filter the rows of a DataFrame with a boolean expression. Both will return DataFrames that are subsets of the original dataframe."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# get Series of True and False
df["column"] < 10

# %%
# get rows of dataframe when condition is True
df[ df["column"] != "Other" ]

# %%
import numpy as np
# get rows when True
df[np.array([True, False, True])]

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Boolean array to get the matching rows

# %%
people[np.array([True, False, True])]
# Out:
#          weight  birthyear  children   hobby
# alice        68       1985       NaN  Biking
# charles     112       1992       0.0     NaN

# %% [markdown]
# ## Boolean expressions to get matching rows

# %%
people["birthyear"] < 1990
# Out:
# alice       True
# bob         True
# charles    False
# Name: birthyear, dtype: bool

# %%
people[people["birthyear"] < 1990]
# Out:
#        weight  birthyear  children    hobby
# alice      68       1985       NaN   Biking
# bob        83       1984       3.0  Dancing

# %%
# Fun Fact: NaN != NaN
people[people["hobby"] == people["hobby"]]
# Out:
#        weight  birthyear  children    hobby
# alice      68       1985       NaN   Biking
# bob        83       1984       3.0  Dancing

# %% [markdown]
# ---
# title: "Add Column to an Existing DataFrame"
# description: "Add a new column to an existing pandas dataframe using a Series or a list. When adding a new column, it is added at the end (on the right) by default. You can also insert a column anywhere else using the insert() method."
# tags: Pandas, Lists
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# add new column to existing df from list
# len(df) *must ==* len(list_of_values)
df['new_column'] = list_of_values

# %%
# use insert to add somewhere else than at the end
df.insert(location_index, 'new_column', list_of_values)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Declaring new column

# %%
people["home"] = ['Boston', 'New York City', 'San Diego']
people
# Out:
#          weight  birthyear  children    hobby           home
# alice        68       1985       NaN   Biking         Boston
# bob          83       1984       3.0  Dancing  New York City
# charles     112       1992       0.0      NaN      San Diego

# %% [markdown]
# When you add a new colum, it must have the same number of rows. Missing rows are filled with NaN, and extra rows are ignored:

# %%
people["pets"] = pd.Series({"bob": 0, "charles": 5, "eugene":1})  # alice is missing, eugene is ignored
people
# Out:
#          weight  birthyear  children    hobby           home  pets
# alice        68       1985       NaN   Biking         Boston   NaN
# bob          83       1984       3.0  Dancing  New York City   0.0
# charles     112       1992       0.0      NaN      San Diego   5.0

# %% [markdown]
# # Example&

# %% [markdown]
# ## Using the `insert` method

# %%
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people.insert(1, "height", [172, 181, 185])
people
# Out:
#          weight  height  birthyear  children    hobby
# alice        68     172       1985       NaN   Biking
# bob          83     181       1984       3.0  Dancing
# charles     112     185       1992       0.0      NaN

# %% [markdown]
# ---
# title: "Add Column to an Existing DataFrame Based off of Values in an Existing Column"
# description: "Add a new column to an existing pandas dataframe. Use a Series, a list, or create a new column based off the values in an existing column."
# tags: Pandas, Lists
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# any operation will be performed element-wisef
df['new_column'] = df['old_column'] / 100

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## New Column Based off of Existing column

# %%
people["age"] = 2019 - people["birthyear"]  # adds a new column "age"
people["over 30"] = people["age"] > 30      # adds another column "over 30"

people
# Out:
#          weight  birthyear  children    hobby  age  over 30
# alice        68       1985       NaN   Biking   34     True
# bob          83       1984       3.0  Dancing   35     True
# charles     112       1992       0.0      NaN   27    False

# %% [markdown]
# ---
# title: "Apply Any Function to an Existing Column"
# description: "Using pandas apply function, you can easily create new columns by applying any function to all the values element-wise in a current column to create a new one. Add Column to a DataFrame Based off of an existing one."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# using a lambda function
df['new_column'] = df['col'].apply(lambda x : x/100)

# %%
# using a function you built
def my_func(x):
    return x*100

df['new_column'] = df['col'].apply(my_func)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Create function

# %%
def is_it_cool(hobby):
    # fun fact: NaN != NaN
    if hobby != hobby:
        return "that's lame"
    return "that's cool"

# %% [markdown]
# ## Apply functions

# %%
people["hobby_review"] = people['hobby'].apply(is_it_cool)
people["weight_lbs"] = people['weight'].apply(lambda x : 2.2*x)

# %%
people
# Out:
#          weight  birthyear  children    hobby hobby_review  weight_lbs
# alice        68       1985       NaN   Biking  that's cool       149.6
# bob          83       1984       3.0  Dancing  that's cool       182.6
# charles     112       1992       0.0      NaN  that's lame       246.4

# %% [markdown]
# ---
# title: "Apply Any Function to an Entire Row"
# description: "Using pandas apply function with axis = 1, you can easily create new columns by applying passing an entire row into a function to create a column with values based off a row. Add A Column to a DataFrame Based off of Many Columns."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
import numpy as np
# using a lambda function
df['new_column'] = df.apply(
            lambda row : row['col_1'] * 100, 
            axis = 1)

# %%
# using a function you built
def my_func(row):
    return (row['col_1'] + row['col_2']) / 2

df['new_column'] = df.apply(my_func, axis = 1)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "height": [172, 181, 185],
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [1, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          height  weight  birthyear  children    hobby
# alice       172      68       1985         1   Biking
# bob         181      83       1984         3  Dancing
# charles     185     112       1992         0      NaN

# %% [markdown]
# ## Create function

# %%
def bmi(row):
    return row["weight"] / (row["height"] / 100) ** 2

# %% [markdown]
# ## Apply functions

# %%
people['body_mass_index'] = people.apply(bmi, axis = 1)
people['meaningless_calculation'] = people.apply(
        lambda row : (row['height'] + row['children']) % 7,
        axis = 1)

# %%
people
# Out:
#          height  weight  birthyear  children    hobby  body_mass_index  \
# alice       172      68       1985         1   Biking        22.985398
# bob         181      83       1984         3  Dancing        25.335002
# charles     185     112       1992         0      NaN        32.724617
#
#          meaningless_calculation
# alice                          5
# bob                            2
# charles                        3

# %% [markdown]
# ---
# title: "Drop a Column from a DataFrame"
# description: "Remove a column or many columns from a pandas dataframe."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# just remove
del df['column']

# %%
# remove and return
series = df.pop('column')

# %% [markdown]
# To drop multiple columns, use the `drop()` method with either `axis = 1` or `columns = ` (it does the same thing). Both return a new dataframe without the unwanted columns.

# %%
df.drop(['col_1', 'col_2', '...'], axis = 1)
# overwrite the original df
df = df.drop(columns = ['col_1', 'col_2', '...'])

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
birthyears = people.pop("birthyear")
birthyears
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
del people["children"]
people
# Out:
#          weight    hobby
# alice        68   Biking
# bob          83  Dancing
# charles     112      NaN

# %%
people.drop(columns = ['weight', 'hobby'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [alice, bob, charles]

# %% [markdown]
# ---
# title: "Drop a Row from a DataFrame"
# description: "Remove a row or many rows from a pandas dataframe."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# drop by index label
df.drop('row_label')
# or
df.drop(['row_label_1', 'row_label_2', '...'])

# %%
# drop by index
df.drop(index)
# or
df.drop([index_1, index_2, ...])

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# ## Dropping with index label

# %%
people.drop('charles')
# Out:
#        weight  birthyear  children    hobby
# alice      68       1985       NaN   Biking
# bob        83       1984       3.0  Dancing

# %% [markdown]
# ## Dropping with index

# %%
people = pd.DataFrame(people_dict)
people
# Out:
#    weight  birthyear  children    hobby
# 0      68       1985       NaN   Biking
# 1      83       1984       3.0  Dancing
# 2     112       1992       0.0      NaN

# %%
people.drop([1,2])
# Out:
#    weight  birthyear  children   hobby
# 0      68       1985       NaN  Biking

# %% [markdown]
# ---
# title: "Assign Columns to a DataFrame"
# description: "Use the assign method to create a new DataFrame object with all the data from a previous DataFrame in attion to new columns. Existing columns that are re-assigned are overwritten by this method. This method lets you assign multiple new columns in one step as well as create new columns that are functions of the values in other rows."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "height": [172, 181, 185],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  height  birthyear  children    hobby
# alice        68     172       1985       NaN   Biking
# bob          83     181       1984       3.0  Dancing
# charles     112     185       1992       0.0      NaN

# %% [markdown]
# ## Assign some new columns

# %%
people.assign(
    body_mass_index = people["weight"] / (people["height"] / 100) ** 2,
    has_kids = people["children"] > 0
)
# Out:
#          weight  height  birthyear  children    hobby  body_mass_index  \
# alice        68     172       1985       NaN   Biking        22.985398
# bob          83     181       1984       3.0  Dancing        25.335002
# charles     112     185       1992       0.0      NaN        32.724617
#
#          has_kids
# alice       False
# bob          True
# charles     False

# %% [markdown]
# Note that you cannot access columns created within the same assignment:

# %%
try:
    people.assign(
        body_mass_index = people["weight"] / (people["height"] / 100) ** 2,
        overweight = people["body_mass_index"] > 25
    )
except KeyError as e:
    print("Key error:", e)
# Out:
# Key error: 'body_mass_index'

# %% [markdown]
# But fear not, there is a simple solution. You can pass a function to the `assign()` method (typically a `lambda` function), and this function will be called with the `DataFrame` as a parameter:

# %%
(people
     .assign(body_mass_index = lambda df: df["weight"] / (df["height"] / 100) ** 2)
     .assign(overweight = lambda df: df["body_mass_index"] > 25)
)
# Out:
#          weight  height  birthyear  children    hobby  body_mass_index  \
# alice        68     172       1985       NaN   Biking        22.985398
# bob          83     181       1984       3.0  Dancing        25.335002
# charles     112     185       1992       0.0      NaN        32.724617
#
#          overweight
# alice         False
# bob            True
# charles        True

# %% [markdown]
# Problem solved!

# %% [markdown]
# ---
# title: "Querying A DataFrame"
# description: "Query the columns of a dataframe with a boolean expression and filter out the rows for which it holds true."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# use 'and' and 'or' to string multiple expressions together
df.query('query_expression')

# %%
# True: these expressions are equal 
df.query('col_1 > col_2') == df[df.col_1 > df.col_2]

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "height": [172, 181, 185],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  height  birthyear  children    hobby
# alice        68     172       1985       NaN   Biking
# bob          83     181       1984       3.0  Dancing
# charles     112     185       1992       0.0      NaN

# %% [markdown]
# ## Make a query

# %%
people.query("weight < 100")
# Out:
#        weight  height  birthyear  children    hobby
# alice      68     172       1985       NaN   Biking
# bob        83     181       1984       3.0  Dancing

# %% [markdown]
# ## String together expressions with `and`, `or`

# %%
people.query("height > 180 and birthyear % 2 == 0")
# Out:
#          weight  height  birthyear  children    hobby
# bob          83     181       1984       3.0  Dancing
# charles     112     185       1992       0.0      NaN

# %% [markdown]
# ---
# title: "Sort a DataFrame by Index Label"
# description: "Query the columns of a dataframe with a boolean expression and filter out the rows for which it holds true."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %% [markdown]
# By default the `sort_index` method sorts by index label and will return a sorted copy of the DataFrame.

# %% [markdown]
# To modify the `df` directly, set the `inplace` argument to `True`.

# %%
df.sort_index(inplace = True)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "height": [172, 181, 185],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  height  birthyear  children    hobby
# alice        68     172       1985       NaN   Biking
# bob          83     181       1984       3.0  Dancing
# charles     112     185       1992       0.0      NaN

# %% [markdown]
# ### The rows are already sorted by their index label in ascending (lexicographical) order, so let's reverse the order.

# %%
people.sort_index(inplace = True, ascending = False)
people
# Out:
#          weight  height  birthyear  children    hobby
# charles     112     185       1992       0.0      NaN
# bob          83     181       1984       3.0  Dancing
# alice        68     172       1985       NaN   Biking

# %% [markdown]
# ---
# title: "Sort a DataFrame by Column"
# description: "Sort a DataFrame by its column names."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %% [markdown]
# By default the `sort_index` method sorts by index label and will return a sorted copy of the DataFrame. We can set `axis = 1` to sort the column names.

# %% [markdown]
# To modify the `df` directly, set the `inplace` argument to `True`.

# %%
df.sort_index(axis = 1, inplace = True)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112],
    "height": [172, 181, 185],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, 0],
    "hobby": ["Biking", "Dancing", np.nan],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  height  birthyear  children    hobby
# alice        68     172       1985       NaN   Biking
# bob          83     181       1984       3.0  Dancing
# charles     112     185       1992       0.0      NaN

# %% [markdown]
# ## Sort the columns in lexicographical order

# %%
people.sort_index(axis = 1)
# Out:
#          birthyear  children  height    hobby  weight
# alice         1985       NaN     172   Biking      68
# bob           1984       3.0     181  Dancing      83
# charles       1992       0.0     185      NaN     112

# %% [markdown]
# ---
# title: "Sort a DataFrame by Values in a Column"
# description: "Sort a DataFrame by the values in one particular column."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %% [markdown]
# By default the `sort_values` method returns a sorted copy of the DataFrame. To modify the `df` directly, set the `inplace` argument to `True`.

# %%
# sort by my_column
df.sort_values(by = 'my_column')

# %%
# sort by multiple columns
df.sort_values(by = ['col_1', 'col_2'])

# %% [markdown]
# To sort in reverse order, set `ascending = False` (default is `True`) <br> To put NaNs at the beginning, set `na_position = 'first'` (default is `'last'`)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
people_dict = {
    "weight": [68, 83, 112, 68, 100],
    "height": [172, 181, 185, 155, 155],
    "birthyear": [1985, 1984, 1992, 2000, 1977],
    "children": [np.nan, 3, 0, 0, 2],
    "hobby": ["Biking", "Dancing", np.nan, "Hockey", "Reading"],
}
people = pd.DataFrame(people_dict)
people
# Out:
#    weight  height  birthyear  children    hobby
# 0      68     172       1985       NaN   Biking
# 1      83     181       1984       3.0  Dancing
# 2     112     185       1992       0.0      NaN
# 3      68     155       2000       0.0   Hockey
# 4     100     155       1977       2.0  Reading

# %% [markdown]
# ## Sort by height

# %%
people.sort_values('height')
# Out:
#    weight  height  birthyear  children    hobby
# 3      68     155       2000       0.0   Hockey
# 4     100     155       1977       2.0  Reading
# 0      68     172       1985       NaN   Biking
# 1      83     181       1984       3.0  Dancing
# 2     112     185       1992       0.0      NaN

# %% [markdown]
# ## Sort by children and birthyear with na first

# %%
people.sort_values(['children', 'birthyear'], na_position = 'first')
# Out:
#    weight  height  birthyear  children    hobby
# 0      68     172       1985       NaN   Biking
# 2     112     185       1992       0.0      NaN
# 3      68     155       2000       0.0   Hockey
# 4     100     155       1977       2.0  Reading
# 1      83     181       1984       3.0  Dancing

# %% [markdown]
# ---
# title: "Aggregate Data into Groups with Groupby"
# description: "Similar to the SQL language, pandas allows you to group your data to run calculations over each group."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# split groups
grouping_object = df.groupby('my_column')

# %%
# split groups and apply a function
grouping_object.mean()

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create some example data

# %%
data = {
    "sept": [8, 10, 4, np.nan, 9],
    "oct": [8, 9, 11, np.nan, 10],
    "nov": [9, 10, 5, np.nan, 11],
    "dec": [np.nan, np.nan, np.nan, np.nan, np.nan],
    "hobby": ['Biking', 'Dancing', np.nan, 'Dancing', 'Biking']
}
final_grades = pd.DataFrame(data, index=["alice", "bob", "charles", 'colin', 'darwin'])

final_grades
# Out:
#          sept   oct   nov  dec    hobby
# alice     8.0   8.0   9.0  NaN   Biking
# bob      10.0   9.0  10.0  NaN  Dancing
# charles   4.0  11.0   5.0  NaN      NaN
# colin     NaN   NaN   NaN  NaN  Dancing
# darwin    9.0  10.0  11.0  NaN   Biking

# %% [markdown]
# ## Create grouping object by hobby

# %%
grouped_grades = final_grades.groupby("hobby")
grouped_grades

# %% [markdown]
# ## Compute the average grade per hobby

# %%
grouped_grades.mean()
# Out:
#          sept  oct   nov  dec
# hobby
# Biking    8.5  9.0  10.0  NaN
# Dancing  10.0  9.0  10.0  NaN

# %% [markdown]
# Note: the `NaN` values have simply been skipped when computing the means.

# %% [markdown]
# # Learn More&

# %% [markdown]
# There's lots to learn about pandas groupby function. Check out the documentation here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %% [markdown]
# ---
# title: "Pivot Tables"
# description: "Create a spreadsheet-like statistical summary of the data as a DataFrame with "
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# by default the pivot table computes numerical mean
pd.pivot_table(df, index = 'my_column')

# %%
# specify the columns to aggregate over horizontally
pd.pivot_table(df, index = 'my_column', columns = 'col')

# %%
# specify the list of columns whose values will be aggregated
pd.pivot_table(df, index = 'my_column', values = ['col_1', 'col_2'])

# %% [markdown]
# ### Other useful parameters:

# %% [markdown]
# - `aggfunc` (function): use something else than the mean. Also this could be a list of functions and the resulting table will have hierarchical columns with the function names at the top.
# - `margins` (default = False): include a grand total for rows and columns
# - `fill_value` (scalar): replace all missing with this value
# - `dropna` (default = True): don't include any columns that have only NaN values

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example data

# %%
data = {
    "sept": [8, 10, 4, 9],
    "oct": [8, 9, 11, 10],
    "nov": [9, 10, 5, 11],
}
grades = pd.DataFrame(data, index=["alice", "bob", "charles", 'darwin'])
grades = grades.stack().reset_index()
grades.columns = ["name", "month", "grade"]
grades['bonus'] = [np.nan, np.nan, np.nan, 0, np.nan, 2, 3, 3, 0, 0, 1, 0]

# %%
grades
# Out:
#        name month  grade  bonus
# 0     alice  sept      8    NaN
# 1     alice   oct      8    NaN
# 2     alice   nov      9    NaN
# 3       bob  sept     10    0.0
# 4       bob   oct      9    NaN
# 5       bob   nov     10    2.0
# 6   charles  sept      4    3.0
# 7   charles   oct     11    3.0
# 8   charles   nov      5    0.0
# 9    darwin  sept      9    0.0
# 10   darwin   oct     10    1.0
# 11   darwin   nov     11    0.0

# %% [markdown]
# ## Groupy by the `name` column
# Now we can call the `pd.pivot_table()` function for this `DataFrame`, asking to group by the `name` column. By default, `pivot_table()` computes the mean of each numeric column:

# %%
pd.pivot_table(grades, index="name")
# Out:
#             bonus      grade
# name
# alice         NaN   8.333333
# bob      1.000000   9.666667
# charles  2.000000   6.666667
# darwin   0.333333  10.000000

# %% [markdown]
# ## Calculate max instead of mean

# %%
pd.pivot_table(grades, index="name", values=["grade","bonus"], aggfunc=np.max)
# Out:
#          bonus  grade
# name
# alice      NaN      9
# bob        2.0     10
# charles    3.0     11
# darwin     1.0     11

# %% [markdown]
# ## Aggregate horizontally over `month` and `margins = True`

# %%
pd.pivot_table(grades, index="name", values="grade", columns="month", margins=True)
# Out:
# month    nov  oct  sept        All
# name
# alice      9    8     8   8.333333
# bob       10    9    10   9.666667
# charles    5   11     4   6.666667
# darwin    11   10     9  10.000000
# All        8    9     7   8.666667

# %% [markdown]
# ## Specify multiple index or column names and pandas will create multi-level indices

# %%
pd.pivot_table(grades, index=("name", "month"), margins=True)
# Out:
#                bonus  grade
# name    month
# alice   nov      NaN      9
#         oct      NaN      8
#         sept     NaN      8
# bob     nov    2.000     10
#         oct      NaN      9
#         sept   0.000     10
# charles nov    0.000      5
#         oct    3.000     11
#         sept   3.000      4
# darwin  nov    0.000     11
#         oct    1.000     10
#         sept   0.000      9
# All            1.125      8

# %% [markdown]
# # Learn More&

# %% [markdown]
# Check out the documentation on pivot tables here to learn more: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html

# %% [markdown]
# ---
# title: "Head of a DataFrame"
# description: "When dealing with large DataFrames, it is useful to get a quick overview of its content. Pandas provides the head function to preview the first n rows of a large DataFrame."
# tags: Pandas, EDA
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# preview first 5 rows by default
df.head()

# %%
# preview first n rows
df.head(n)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create large example DataFrame

# %%
much_data_such_wow = np.fromfunction(lambda x,y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data_such_wow, columns=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(3,"some_text", "very nice")
large_df
# Out:
#           A      B      C  some_text      D      E      F      G      H  \
# 0       NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 1      11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 2      22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 3      33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 4      44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 5      55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 6      66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 7      77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 8      88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9      99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 10    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 11    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 12    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 13    143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 14    154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 15    165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 16      NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 17      NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 18     11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 19     22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 20     33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 21     44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 22     55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 23     66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 24     77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 25     88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 26     99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 27    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 28    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 29    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# ...     ...    ...    ...        ...    ...    ...    ...    ...    ...
# 9970   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9971   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9972  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9973  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9974  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9975  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9976  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9977  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9978    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9979    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9980   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9981   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9982   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 9983   44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 9984   55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 9985   66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 9986   77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 9987   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9988   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9989  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9990  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9991  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9992  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9993  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9994  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9995    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9996    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9997   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9998   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9999   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
#
#           I  ...        Q      R      S      T      U      V      W      X  \
# 0     143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 1     154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 2     165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 3       NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 4       NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 5      11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 6      22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 7      33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 8      44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9      55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 10     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 11     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 12     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 13     99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 14    110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 15    121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 16    132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 17    143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 18    154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 19    165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 20      NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 21      NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 22     11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 23     22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 24     33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 25     44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 26     55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 27     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 28     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 29     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# ...     ...  ...      ...    ...    ...    ...    ...    ...    ...    ...
# 9970   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9971   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9972   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9973   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9974   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9975   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9976  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9977  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9978  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9979  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9980  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9981  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9982    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 9983    NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 9984   11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 9985   22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 9986   33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 9987   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9988   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9989   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9990   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9991   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9992   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9993  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9994  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9995  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9996  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9997  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9998  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9999    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
#
#           Y      Z
# 0     165.0  143.0
# 1       NaN  154.0
# 2       NaN  165.0
# 3      11.0    NaN
# 4      22.0    NaN
# 5      33.0   11.0
# 6      44.0   22.0
# 7      55.0   33.0
# 8      66.0   44.0
# 9      77.0   55.0
# 10     88.0   66.0
# 11     99.0   77.0
# 12    110.0   88.0
# 13    121.0   99.0
# 14    132.0  110.0
# 15    143.0  121.0
# 16    154.0  132.0
# 17    165.0  143.0
# 18      NaN  154.0
# 19      NaN  165.0
# 20     11.0    NaN
# 21     22.0    NaN
# 22     33.0   11.0
# 23     44.0   22.0
# 24     55.0   33.0
# 25     66.0   44.0
# 26     77.0   55.0
# 27     88.0   66.0
# 28     99.0   77.0
# 29    110.0   88.0
# ...     ...    ...
# 9970   66.0   44.0
# 9971   77.0   55.0
# 9972   88.0   66.0
# 9973   99.0   77.0
# 9974  110.0   88.0
# 9975  121.0   99.0
# 9976  132.0  110.0
# 9977  143.0  121.0
# 9978  154.0  132.0
# 9979  165.0  143.0
# 9980    NaN  154.0
# 9981    NaN  165.0
# 9982   11.0    NaN
# 9983   22.0    NaN
# 9984   33.0   11.0
# 9985   44.0   22.0
# 9986   55.0   33.0
# 9987   66.0   44.0
# 9988   77.0   55.0
# 9989   88.0   66.0
# 9990   99.0   77.0
# 9991  110.0   88.0
# 9992  121.0   99.0
# 9993  132.0  110.0
# 9994  143.0  121.0
# 9995  154.0  132.0
# 9996  165.0  143.0
# 9997    NaN  154.0
# 9998    NaN  165.0
# 9999   11.0    NaN
#
# [10000 rows x 27 columns]

# %% [markdown]
# ## Using the head function

# %%
large_df.head()
# Out:
#       A     B     C  some_text      D     E      F     G      H      I  ...    \
# 0   NaN  11.0  44.0  very nice   99.0   NaN   88.0  22.0  165.0  143.0  ...
# 1  11.0  22.0  55.0  very nice  110.0   NaN   99.0  33.0    NaN  154.0  ...
# 2  22.0  33.0  66.0  very nice  121.0  11.0  110.0  44.0    NaN  165.0  ...
# 3  33.0  44.0  77.0  very nice  132.0  22.0  121.0  55.0   11.0    NaN  ...
# 4  44.0  55.0  88.0  very nice  143.0  33.0  132.0  66.0   22.0    NaN  ...
#
#       Q     R     S     T      U     V      W     X      Y      Z
# 0  11.0   NaN  11.0  44.0   99.0   NaN   88.0  22.0  165.0  143.0
# 1  22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0    NaN  154.0
# 2  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0    NaN  165.0
# 3  44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0   11.0    NaN
# 4  55.0  44.0  55.0  88.0  143.0  33.0  132.0  66.0   22.0    NaN
#
# [5 rows x 27 columns]

# %%
large_df.head(3)
# Out:
#       A     B     C  some_text      D     E      F     G      H      I  ...    \
# 0   NaN  11.0  44.0  very nice   99.0   NaN   88.0  22.0  165.0  143.0  ...
# 1  11.0  22.0  55.0  very nice  110.0   NaN   99.0  33.0    NaN  154.0  ...
# 2  22.0  33.0  66.0  very nice  121.0  11.0  110.0  44.0    NaN  165.0  ...
#
#       Q     R     S     T      U     V      W     X      Y      Z
# 0  11.0   NaN  11.0  44.0   99.0   NaN   88.0  22.0  165.0  143.0
# 1  22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0    NaN  154.0
# 2  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0    NaN  165.0
#
# [3 rows x 27 columns]

# %% [markdown]
# ---
# title: "Tail of a DataFrame"
# description: "When dealing with large DataFrames, it is useful to get a quick overview of its content. Pandas provides the tail function to preview the last n rows of a large DataFrame."
# tags: Pandas, EDA
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# preview last 5 rows by default
df.tail()

# %%
# preview last n rows
df.tail(n)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create large example DataFrame

# %%
much_data_such_wow = np.fromfunction(lambda x,y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data_such_wow, columns=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(3,"some_text", "very nice")
large_df
# Out:
#           A      B      C  some_text      D      E      F      G      H  \
# 0       NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 1      11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 2      22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 3      33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 4      44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 5      55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 6      66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 7      77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 8      88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9      99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 10    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 11    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 12    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 13    143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 14    154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 15    165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 16      NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 17      NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 18     11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 19     22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 20     33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 21     44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 22     55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 23     66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 24     77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 25     88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 26     99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 27    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 28    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 29    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# ...     ...    ...    ...        ...    ...    ...    ...    ...    ...
# 9970   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9971   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9972  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9973  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9974  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9975  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9976  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9977  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9978    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9979    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9980   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9981   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9982   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 9983   44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 9984   55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 9985   66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 9986   77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 9987   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9988   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9989  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9990  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9991  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9992  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9993  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9994  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9995    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9996    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9997   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9998   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9999   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
#
#           I  ...        Q      R      S      T      U      V      W      X  \
# 0     143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 1     154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 2     165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 3       NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 4       NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 5      11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 6      22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 7      33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 8      44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9      55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 10     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 11     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 12     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 13     99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 14    110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 15    121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 16    132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 17    143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 18    154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 19    165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 20      NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 21      NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 22     11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 23     22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 24     33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 25     44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 26     55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 27     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 28     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 29     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# ...     ...  ...      ...    ...    ...    ...    ...    ...    ...    ...
# 9970   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9971   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9972   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9973   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9974   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9975   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9976  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9977  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9978  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9979  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9980  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9981  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9982    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 9983    NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 9984   11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 9985   22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 9986   33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 9987   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9988   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9989   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9990   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9991   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9992   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9993  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9994  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9995  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9996  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9997  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9998  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9999    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
#
#           Y      Z
# 0     165.0  143.0
# 1       NaN  154.0
# 2       NaN  165.0
# 3      11.0    NaN
# 4      22.0    NaN
# 5      33.0   11.0
# 6      44.0   22.0
# 7      55.0   33.0
# 8      66.0   44.0
# 9      77.0   55.0
# 10     88.0   66.0
# 11     99.0   77.0
# 12    110.0   88.0
# 13    121.0   99.0
# 14    132.0  110.0
# 15    143.0  121.0
# 16    154.0  132.0
# 17    165.0  143.0
# 18      NaN  154.0
# 19      NaN  165.0
# 20     11.0    NaN
# 21     22.0    NaN
# 22     33.0   11.0
# 23     44.0   22.0
# 24     55.0   33.0
# 25     66.0   44.0
# 26     77.0   55.0
# 27     88.0   66.0
# 28     99.0   77.0
# 29    110.0   88.0
# ...     ...    ...
# 9970   66.0   44.0
# 9971   77.0   55.0
# 9972   88.0   66.0
# 9973   99.0   77.0
# 9974  110.0   88.0
# 9975  121.0   99.0
# 9976  132.0  110.0
# 9977  143.0  121.0
# 9978  154.0  132.0
# 9979  165.0  143.0
# 9980    NaN  154.0
# 9981    NaN  165.0
# 9982   11.0    NaN
# 9983   22.0    NaN
# 9984   33.0   11.0
# 9985   44.0   22.0
# 9986   55.0   33.0
# 9987   66.0   44.0
# 9988   77.0   55.0
# 9989   88.0   66.0
# 9990   99.0   77.0
# 9991  110.0   88.0
# 9992  121.0   99.0
# 9993  132.0  110.0
# 9994  143.0  121.0
# 9995  154.0  132.0
# 9996  165.0  143.0
# 9997    NaN  154.0
# 9998    NaN  165.0
# 9999   11.0    NaN
#
# [10000 rows x 27 columns]

# %% [markdown]
# ## Using the tail function

# %%
large_df.tail()
# Out:
#          A     B     C  some_text      D      E      F     G      H      I  \
# 9995   NaN   NaN  33.0  very nice   88.0  165.0   77.0  11.0  154.0  132.0
# 9996   NaN  11.0  44.0  very nice   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  11.0  22.0  55.0  very nice  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  22.0  33.0  66.0  very nice  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  33.0  44.0  77.0  very nice  132.0   22.0  121.0  55.0   11.0    NaN
#
#       ...       Q     R     S     T      U      V      W     X      Y      Z
# 9995  ...     NaN   NaN   NaN  33.0   88.0  165.0   77.0  11.0  154.0  132.0
# 9996  ...    11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  ...    22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  ...    33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  ...    44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
#
# [5 rows x 27 columns]

# %%
large_df.tail(3)
# Out:
#          A     B     C  some_text      D     E      F     G     H      I  \
# 9997  11.0  22.0  55.0  very nice  110.0   NaN   99.0  33.0   NaN  154.0
# 9998  22.0  33.0  66.0  very nice  121.0  11.0  110.0  44.0   NaN  165.0
# 9999  33.0  44.0  77.0  very nice  132.0  22.0  121.0  55.0  11.0    NaN
#
#       ...       Q     R     S     T      U     V      W     X     Y      Z
# 9997  ...    22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0   NaN  154.0
# 9998  ...    33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0   NaN  165.0
# 9999  ...    44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0  11.0    NaN
#
# [3 rows x 27 columns]

# %% [markdown]
# ---
# title: "Info Overview for a DataFrame"
# description: "When dealing with large DataFrames, it is useful to get a quick overview of its content. Pandas provides the info function which gives a summary of each columns contents."
# tags: Pandas, EDA
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
df.info()

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create large example DataFrame

# %%
much_data_such_wow = np.fromfunction(lambda x,y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data_such_wow, columns=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(3,"some_text", "very nice")
large_df
# Out:
#           A      B      C  some_text      D      E      F      G      H  \
# 0       NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 1      11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 2      22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 3      33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 4      44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 5      55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 6      66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 7      77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 8      88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9      99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 10    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 11    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 12    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 13    143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 14    154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 15    165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 16      NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 17      NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 18     11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 19     22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 20     33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 21     44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 22     55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 23     66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 24     77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 25     88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 26     99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 27    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 28    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 29    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# ...     ...    ...    ...        ...    ...    ...    ...    ...    ...
# 9970   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9971   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9972  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9973  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9974  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9975  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9976  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9977  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9978    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9979    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9980   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9981   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9982   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 9983   44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 9984   55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 9985   66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 9986   77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 9987   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9988   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9989  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9990  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9991  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9992  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9993  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9994  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9995    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9996    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9997   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9998   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9999   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
#
#           I  ...        Q      R      S      T      U      V      W      X  \
# 0     143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 1     154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 2     165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 3       NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 4       NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 5      11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 6      22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 7      33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 8      44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9      55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 10     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 11     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 12     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 13     99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 14    110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 15    121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 16    132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 17    143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 18    154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 19    165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 20      NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 21      NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 22     11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 23     22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 24     33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 25     44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 26     55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 27     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 28     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 29     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# ...     ...  ...      ...    ...    ...    ...    ...    ...    ...    ...
# 9970   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9971   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9972   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9973   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9974   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9975   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9976  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9977  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9978  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9979  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9980  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9981  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9982    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 9983    NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 9984   11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 9985   22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 9986   33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 9987   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9988   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9989   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9990   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9991   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9992   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9993  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9994  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9995  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9996  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9997  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9998  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9999    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
#
#           Y      Z
# 0     165.0  143.0
# 1       NaN  154.0
# 2       NaN  165.0
# 3      11.0    NaN
# 4      22.0    NaN
# 5      33.0   11.0
# 6      44.0   22.0
# 7      55.0   33.0
# 8      66.0   44.0
# 9      77.0   55.0
# 10     88.0   66.0
# 11     99.0   77.0
# 12    110.0   88.0
# 13    121.0   99.0
# 14    132.0  110.0
# 15    143.0  121.0
# 16    154.0  132.0
# 17    165.0  143.0
# 18      NaN  154.0
# 19      NaN  165.0
# 20     11.0    NaN
# 21     22.0    NaN
# 22     33.0   11.0
# 23     44.0   22.0
# 24     55.0   33.0
# 25     66.0   44.0
# 26     77.0   55.0
# 27     88.0   66.0
# 28     99.0   77.0
# 29    110.0   88.0
# ...     ...    ...
# 9970   66.0   44.0
# 9971   77.0   55.0
# 9972   88.0   66.0
# 9973   99.0   77.0
# 9974  110.0   88.0
# 9975  121.0   99.0
# 9976  132.0  110.0
# 9977  143.0  121.0
# 9978  154.0  132.0
# 9979  165.0  143.0
# 9980    NaN  154.0
# 9981    NaN  165.0
# 9982   11.0    NaN
# 9983   22.0    NaN
# 9984   33.0   11.0
# 9985   44.0   22.0
# 9986   55.0   33.0
# 9987   66.0   44.0
# 9988   77.0   55.0
# 9989   88.0   66.0
# 9990   99.0   77.0
# 9991  110.0   88.0
# 9992  121.0   99.0
# 9993  132.0  110.0
# 9994  143.0  121.0
# 9995  154.0  132.0
# 9996  165.0  143.0
# 9997    NaN  154.0
# 9998    NaN  165.0
# 9999   11.0    NaN
#
# [10000 rows x 27 columns]

# %% [markdown]
# ## Get the info

# %%
large_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
# A            8823 non-null float64
# B            8824 non-null float64
# C            8824 non-null float64
# some_text    10000 non-null object
# D            8824 non-null float64
# E            8822 non-null float64
# F            8824 non-null float64
# G            8824 non-null float64
# H            8822 non-null float64
# I            8823 non-null float64
# J            8823 non-null float64
# K            8822 non-null float64
# L            8824 non-null float64
# M            8824 non-null float64
# N            8822 non-null float64
# O            8824 non-null float64
# P            8824 non-null float64
# Q            8824 non-null float64
# R            8823 non-null float64
# S            8824 non-null float64
# T            8824 non-null float64
# U            8824 non-null float64
# V            8822 non-null float64
# W            8824 non-null float64
# X            8824 non-null float64
# Y            8822 non-null float64
# Z            8823 non-null float64
# dtypes: float64(26), object(1)
# memory usage: 2.1+ MB

# %% [markdown]
# ---
# title: "Describe for a DataFrame"
# description: "When dealing with large DataFrames, it is useful to get a quick overview of its content. Pandas provides the describe function which gives a nice overview of the main aggregated values over each column."
# tags: Pandas, EDA
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
df.describe()

# %% [markdown]
# The `describe()` method gives a nice overview of the main aggregated values over each column:
# * `count`: number of non-null (not NaN) values
# * `mean`: mean of non-null values
# * `std`: [standard deviation](https://en.wikipedia.org/wiki/Standard_deviation) of non-null values
# * `min`: minimum of non-null values
# * `25%`, `50%`, `75%`: 25th, 50th and 75th [percentile](https://en.wikipedia.org/wiki/Percentile) of non-null values
# * `max`: maximum of non-null values

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create large example DataFrame

# %%
much_data_such_wow = np.fromfunction(lambda x,y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data_such_wow, columns=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(3,"some_text", "very nice")
large_df
# Out:
#           A      B      C  some_text      D      E      F      G      H  \
# 0       NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 1      11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 2      22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 3      33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 4      44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 5      55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 6      66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 7      77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 8      88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9      99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 10    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 11    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 12    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 13    143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 14    154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 15    165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 16      NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 17      NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 18     11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 19     22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 20     33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 21     44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 22     55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 23     66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 24     77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 25     88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 26     99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 27    110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 28    121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 29    132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# ...     ...    ...    ...        ...    ...    ...    ...    ...    ...
# 9970   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9971   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9972  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9973  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9974  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9975  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9976  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9977  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9978    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9979    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9980   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9981   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9982   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
# 9983   44.0   55.0   88.0  very nice  143.0   33.0  132.0   66.0   22.0
# 9984   55.0   66.0   99.0  very nice  154.0   44.0  143.0   77.0   33.0
# 9985   66.0   77.0  110.0  very nice  165.0   55.0  154.0   88.0   44.0
# 9986   77.0   88.0  121.0  very nice    NaN   66.0  165.0   99.0   55.0
# 9987   88.0   99.0  132.0  very nice    NaN   77.0    NaN  110.0   66.0
# 9988   99.0  110.0  143.0  very nice   11.0   88.0    NaN  121.0   77.0
# 9989  110.0  121.0  154.0  very nice   22.0   99.0   11.0  132.0   88.0
# 9990  121.0  132.0  165.0  very nice   33.0  110.0   22.0  143.0   99.0
# 9991  132.0  143.0    NaN  very nice   44.0  121.0   33.0  154.0  110.0
# 9992  143.0  154.0    NaN  very nice   55.0  132.0   44.0  165.0  121.0
# 9993  154.0  165.0   11.0  very nice   66.0  143.0   55.0    NaN  132.0
# 9994  165.0    NaN   22.0  very nice   77.0  154.0   66.0    NaN  143.0
# 9995    NaN    NaN   33.0  very nice   88.0  165.0   77.0   11.0  154.0
# 9996    NaN   11.0   44.0  very nice   99.0    NaN   88.0   22.0  165.0
# 9997   11.0   22.0   55.0  very nice  110.0    NaN   99.0   33.0    NaN
# 9998   22.0   33.0   66.0  very nice  121.0   11.0  110.0   44.0    NaN
# 9999   33.0   44.0   77.0  very nice  132.0   22.0  121.0   55.0   11.0
#
#           I  ...        Q      R      S      T      U      V      W      X  \
# 0     143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 1     154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 2     165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 3       NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 4       NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 5      11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 6      22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 7      33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 8      44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9      55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 10     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 11     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 12     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 13     99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 14    110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 15    121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 16    132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 17    143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 18    154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 19    165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 20      NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 21      NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 22     11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 23     22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 24     33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 25     44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 26     55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 27     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 28     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 29     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# ...     ...  ...      ...    ...    ...    ...    ...    ...    ...    ...
# 9970   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9971   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9972   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9973   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9974   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9975   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9976  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9977  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9978  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9979  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9980  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9981  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9982    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 9983    NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 9984   11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 9985   22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 9986   33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 9987   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9988   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9989   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9990   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9991   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9992   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9993  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9994  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9995  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9996  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9997  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9998  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9999    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
#
#           Y      Z
# 0     165.0  143.0
# 1       NaN  154.0
# 2       NaN  165.0
# 3      11.0    NaN
# 4      22.0    NaN
# 5      33.0   11.0
# 6      44.0   22.0
# 7      55.0   33.0
# 8      66.0   44.0
# 9      77.0   55.0
# 10     88.0   66.0
# 11     99.0   77.0
# 12    110.0   88.0
# 13    121.0   99.0
# 14    132.0  110.0
# 15    143.0  121.0
# 16    154.0  132.0
# 17    165.0  143.0
# 18      NaN  154.0
# 19      NaN  165.0
# 20     11.0    NaN
# 21     22.0    NaN
# 22     33.0   11.0
# 23     44.0   22.0
# 24     55.0   33.0
# 25     66.0   44.0
# 26     77.0   55.0
# 27     88.0   66.0
# 28     99.0   77.0
# 29    110.0   88.0
# ...     ...    ...
# 9970   66.0   44.0
# 9971   77.0   55.0
# 9972   88.0   66.0
# 9973   99.0   77.0
# 9974  110.0   88.0
# 9975  121.0   99.0
# 9976  132.0  110.0
# 9977  143.0  121.0
# 9978  154.0  132.0
# 9979  165.0  143.0
# 9980    NaN  154.0
# 9981    NaN  165.0
# 9982   11.0    NaN
# 9983   22.0    NaN
# 9984   33.0   11.0
# 9985   44.0   22.0
# 9986   55.0   33.0
# 9987   66.0   44.0
# 9988   77.0   55.0
# 9989   88.0   66.0
# 9990   99.0   77.0
# 9991  110.0   88.0
# 9992  121.0   99.0
# 9993  132.0  110.0
# 9994  143.0  121.0
# 9995  154.0  132.0
# 9996  165.0  143.0
# 9997    NaN  154.0
# 9998    NaN  165.0
# 9999   11.0    NaN
#
# [10000 rows x 27 columns]

# %% [markdown]
# ## Get the summary

# %%
large_df.describe()
# Out:
#                  A            B            C            D            E  \
# count  8823.000000  8824.000000  8824.000000  8824.000000  8822.000000
# mean     87.977559    87.972575    87.987534    88.012466    87.983791
# std      47.535911    47.535523    47.521679    47.521679    47.535001
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  F            G            H            I            J  \
# count  8824.000000  8824.000000  8822.000000  8823.000000  8823.000000
# mean     88.007480    87.977561    88.000000    88.022441    88.022441
# std      47.519371    47.529755    47.536879    47.535911    47.535911
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#           ...                 Q            R            S            T  \
# count     ...       8824.000000  8823.000000  8824.000000  8824.000000
# mean      ...         87.972575    87.977559    87.972575    87.987534
# std       ...         47.535523    47.535911    47.535523    47.521679
# min       ...         11.000000    11.000000    11.000000    11.000000
# 25%       ...         44.000000    44.000000    44.000000    44.000000
# 50%       ...         88.000000    88.000000    88.000000    88.000000
# 75%       ...        132.000000   132.000000   132.000000   132.000000
# max       ...        165.000000   165.000000   165.000000   165.000000
#
#                  U            V            W            X            Y  \
# count  8824.000000  8822.000000  8824.000000  8824.000000  8822.000000
# mean     88.012466    87.983791    88.007480    87.977561    88.000000
# std      47.521679    47.535001    47.519371    47.529755    47.536879
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  Z
# count  8823.000000
# mean     88.022441
# std      47.535911
# min      11.000000
# 25%      44.000000
# 50%      88.000000
# 75%     132.000000
# max     165.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ---
# title: "Save a DataFrame as CSV, HTML, or JSON"
# description: "Pandas can save DataFrames to various backends including file formats such as csv, html, or json."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "Data Import / Connectivity / Injest"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
df.to_csv("filename.csv")

# %%
df.to_html("filename.html")

# %%
df.to_json("filename.json")

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create an example DataFrame

# %%
my_df = pd.DataFrame(
    [["Biking", 68.5, 1985, np.nan], ["Dancing", 83.1, 1984, 3]], 
    columns=["hobby","weight","birthyear","children"],
    index=["alice", "bob"]
)
my_df
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %% [markdown]
# ## Save to a file

# %%
my_df.to_csv("my_df.csv")
my_df.to_html("my_df.html")
my_df.to_json("my_df.json")

# %% [markdown]
# ## Done! Let's peek at the files to make sure

# %%
for filename in ("my_df.csv", "my_df.html", "my_df.json"):
    print("#", filename)
    with open(filename, "rt") as f:
        print(f.read())
        print()
# Out:
# # my_df.csv
# ,hobby,weight,birthyear,children
# alice,Biking,68.5,1985,
# bob,Dancing,83.1,1984,3.0
#
#
# # my_df.html
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hobby</th>
#       <th>weight</th>
#       <th>birthyear</th>
#       <th>children</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alice</th>
#       <td>Biking</td>
#       <td>68.5</td>
#       <td>1985</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>bob</th>
#       <td>Dancing</td>
#       <td>83.1</td>
#       <td>1984</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
#
# # my_df.json
# {"hobby":{"alice":"Biking","bob":"Dancing"},"weight":{"alice":68.5,"bob":83.1},"birthyear":{"alice":1985,"bob":1984},"children":{"alice":null,"bob":3.0}}

# %% [markdown]
# **Note:** the index is saved as the first column (with no name) in a CSV file, as `<th>` tags in HTML and as keys in JSON.

# %% [markdown]
# Saving to other formats works very similarly, but some formats require extra libraries to be installed. For example, saving to Excel requires the openpyxl library:

# %%
try:
    my_df.to_excel("my_df.xlsx", sheet_name='People')
except ImportError as e:
    print(e)
# Out:
# No module named 'openpyxl'

# %% [markdown]
# ---
# title: "Load Data from CSV, HTML, JSON, or Excel"
# description: "Pandas can easily load various file formats such as csv, html, json, or excel into a DataFrame."
# tags: Pandas, Data Import / Connectivity / Injest
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
df = pd.read_csv('filename.csv', index_col = 0)

# %%
# for other file formats, there are similar functions
df = pd.read_json('filename.json')
df = pd.read_html('filename.html')
df = pd.read_excel('filename.xlsx')

# %% [markdown]
# # Example&

# %%
my_df_loaded = pd.read_csv("my_df.csv", index_col=0)
my_df_loaded
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %% [markdown]
# # Learn More&

# %% [markdown]
# There are more options available, in particular regarding datetime format. Check out the [documentation](http://pandas.pydata.org/pandas-docs/stable/io.html) for more details. <br>
# Check out the read_csv documentation here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %% [markdown]
# ---
# title: "Combine DataFrames with the Merge Function"
# description: "One powerful feature of pandas is it's ability to perform SQL-like joins on DataFrames. Various types of joins are supported: inner joins, left/right outer joins and full joins."
# tags: Pandas, Data Import / Connectivity / Injest
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# keeping only rows that have values in both dfs
# equivalent of a SQL 'INNER JOIN'
pd.merge(left = df1, right = df2, on = 'column')

# %%
# where no rows get dopped (missing values just filled with NaN)
# equivalent of a SQL 'FULL OUTER JOIN'
pd.merge(left = df1, right = df2, on = 'column', how = 'outer')

# %% [markdown]
# A SQL `LEFT OUTER JOIN` or `RIGHT OUTER JOIN` (when only the rows existing in the left/right DataFrame end up in the result) .can be achieved by setting `how = 'left'` or `how = 'right'`

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create a couple simple `DataFrame`s:

# %%
city_loc = pd.DataFrame(
    [
        ["CA", "San Francisco", 37.781334, -122.416728],
        ["NY", "New York", 40.705649, -74.008344],
        ["FL", "Miami", 25.791100, -80.320733],
        ["OH", "Cleveland", 41.473508, -81.739791],
        ["UT", "Salt Lake City", 40.755851, -111.896657]
    ], columns=["state", "city", "lat", "lng"])
city_loc
# Out:
#   state            city        lat         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"])
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %% [markdown]
# ## Join these `DataFrame`s using the `merge()` function:

# %%
pd.merge(left=city_loc, right=city_pop, on="city")
# Out:
#   state_x           city        lat         lng  population     state_y
# 0      CA  San Francisco  37.781334 -122.416728      808976  California
# 1      NY       New York  40.705649  -74.008344     8363710    New-York
# 2      FL          Miami  25.791100  -80.320733      413201     Florida

# %% [markdown]
# **Note:** both `DataFrame`s have a column named `state`, so in the result they got renamed to `state_x` and `state_y`.
#
# **Note:** Cleveland, Salt Lake City and Houston were dropped because they don't exist in *both* `DataFrame`s.

# %% [markdown]
# # Example&

# %% [markdown]
# ## Merge where no city gets dropped and `NaN` values are added

# %%
all_cities = pd.merge(left=city_loc, right=city_pop, on="city", how="outer")
all_cities
# Out:
#   state_x            city        lat         lng  population     state_y
# 0      CA   San Francisco  37.781334 -122.416728    808976.0  California
# 1      NY        New York  40.705649  -74.008344   8363710.0    New-York
# 2      FL           Miami  25.791100  -80.320733    413201.0     Florida
# 3      OH       Cleveland  41.473508  -81.739791         NaN         NaN
# 4      UT  Salt Lake City  40.755851 -111.896657         NaN         NaN
# 5     NaN         Houston        NaN         NaN   2242193.0       Texas

# %% [markdown]
# # Example&

# %% [markdown]
# ## Right outer join

# %%
pd.merge(left=city_loc, right=city_pop, on="city", how="right")
# Out:
#   state_x           city        lat         lng  population     state_y
# 0      CA  San Francisco  37.781334 -122.416728      808976  California
# 1      NY       New York  40.705649  -74.008344     8363710    New-York
# 2      FL          Miami  25.791100  -80.320733      413201     Florida
# 3     NaN        Houston        NaN         NaN     2242193       Texas

# %% [markdown]
# # Example&

# %% [markdown]
# If the key to join on is actually in one (or both) `DataFrame`'s index, you must use `left_index=True` and/or `right_index=True`. If the key column names differ, you must use `left_on` and `right_on`. For example:

# %%
city_pop2 = city_pop.copy()
city_pop2.columns = ["population", "name", "state"]
pd.merge(left=city_loc, right=city_pop2, left_on="city", right_on="name")
# Out:
#   state_x           city        lat         lng  population           name  \
# 0      CA  San Francisco  37.781334 -122.416728      808976  San Francisco
# 1      NY       New York  40.705649  -74.008344     8363710       New York
# 2      FL          Miami  25.791100  -80.320733      413201          Miami
#
#       state_y
# 0  California
# 1    New-York
# 2     Florida

# %% [markdown]
# ---
# title: "Concatenate DataFrames with the Concat Function"
# description: "Concatenate multiple DataFrames with the pandas concat() function."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# igonre_index will rename the index 0 ... n-1 (default = False)
pd.concat([df1, df2, df...], ignore_index = True)

# %%
# only columns that exist in both DataFrames are returned
pd.concat([df1, df2, df...], join = 'inner')

# %%
# concatenate horizontally
pd.concat([df1, df2, df...], axis = 1)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrames

# %%
city_loc = pd.DataFrame(
    [
        ["CA", "San Francisco", 37.781334, -122.416728],
        ["NY", "New York", 40.705649, -74.008344],
        ["FL", "Miami", 25.791100, -80.320733],
        ["OH", "Cleveland", 41.473508, -81.739791],
        ["UT", "Salt Lake City", 40.755851, -111.896657]
    ], columns=["state", "city", "lat", "lng"])
city_loc
# Out:
#   state            city        lat         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"])
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %% [markdown]
# ## Concatenate them together

# %%
result_concat = pd.concat([city_loc, city_pop])
result_concat
# Out:
#              city        lat         lng  population       state
# 0   San Francisco  37.781334 -122.416728         NaN          CA
# 1        New York  40.705649  -74.008344         NaN          NY
# 2           Miami  25.791100  -80.320733         NaN          FL
# 3       Cleveland  41.473508  -81.739791         NaN          OH
# 4  Salt Lake City  40.755851 -111.896657         NaN          UT
# 3   San Francisco        NaN         NaN    808976.0  California
# 4        New York        NaN         NaN   8363710.0    New-York
# 5           Miami        NaN         NaN    413201.0     Florida
# 6         Houston        NaN         NaN   2242193.0       Texas

# %% [markdown]
# **Note:** this operation aligned the data horizontally (by columns) but not vertically (by rows). In this example, we end up with multiple rows having the same index (eg. 3). Pandas handles this rather gracefully:

# %%
result_concat.loc[3]
# Out:
#             city        lat        lng  population       state
# 3      Cleveland  41.473508 -81.739791         NaN          OH
# 3  San Francisco        NaN        NaN    808976.0  California

# %% [markdown]
# # Example&

# %% [markdown]
# ## Tell pandas to just ignore the index

# %%
pd.concat([city_loc, city_pop], ignore_index=True)
# Out:
#              city        lat         lng  population       state
# 0   San Francisco  37.781334 -122.416728         NaN          CA
# 1        New York  40.705649  -74.008344         NaN          NY
# 2           Miami  25.791100  -80.320733         NaN          FL
# 3       Cleveland  41.473508  -81.739791         NaN          OH
# 4  Salt Lake City  40.755851 -111.896657         NaN          UT
# 5   San Francisco        NaN         NaN    808976.0  California
# 6        New York        NaN         NaN   8363710.0    New-York
# 7           Miami        NaN         NaN    413201.0     Florida
# 8         Houston        NaN         NaN   2242193.0       Texas

# %% [markdown]
# **Note:** when a column does not exist in a `DataFrame`, it acts as if it was filled with `NaN` values.

# %% [markdown]
# # Example&

# %% [markdown]
# ## Only columns that exist in *both* `DataFrame`s

# %%
pd.concat([city_loc, city_pop], join="inner")
# Out:
#         state            city
# 0          CA   San Francisco
# 1          NY        New York
# 2          FL           Miami
# 3          OH       Cleveland
# 4          UT  Salt Lake City
# 3  California   San Francisco
# 4    New-York        New York
# 5     Florida           Miami
# 6       Texas         Houston

# %% [markdown]
# # Example&

# %% [markdown]
# ## Concatenate `DataFrame`s horizontally

# %%
pd.concat([city_loc, city_pop], axis=1)
# Out:
#   state            city        lat         lng  population           city  \
# 0    CA   San Francisco  37.781334 -122.416728         NaN            NaN
# 1    NY        New York  40.705649  -74.008344         NaN            NaN
# 2    FL           Miami  25.791100  -80.320733         NaN            NaN
# 3    OH       Cleveland  41.473508  -81.739791    808976.0  San Francisco
# 4    UT  Salt Lake City  40.755851 -111.896657   8363710.0       New York
# 5   NaN             NaN        NaN         NaN    413201.0          Miami
# 6   NaN             NaN        NaN         NaN   2242193.0        Houston
#
#         state
# 0         NaN
# 1         NaN
# 2         NaN
# 3  California
# 4    New-York
# 5     Florida
# 6       Texas

# %% [markdown]
# In this case it really does not make much sense because the indices do not align well (eg. Cleveland and San Francisco end up on the same row, because they shared the index label `3`). So let's reindex the `DataFrame`s by city name before concatenating:

# %%
pd.concat([city_loc.set_index("city"), city_pop.set_index("city")], axis=1)
# Out:
#                state        lat         lng  population       state
# Cleveland         OH  41.473508  -81.739791         NaN         NaN
# Houston          NaN        NaN         NaN   2242193.0       Texas
# Miami             FL  25.791100  -80.320733    413201.0     Florida
# New York          NY  40.705649  -74.008344   8363710.0    New-York
# Salt Lake City    UT  40.755851 -111.896657         NaN         NaN
# San Francisco     CA  37.781334 -122.416728    808976.0  California

# %% [markdown]
# This looks a lot like a `FULL OUTER JOIN`, except that the `state` columns were not renamed to `state_x` and `state_y`, and the `city` column is now the index.

# %% [markdown]
# # Learn More&

# %% [markdown]
# Check out [the documentation on pd.concat](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) for more details.

# %% [markdown]
# ---
# title: "Append DataFrames Vertically"
# description: "The append method is a useful shorthand for concatenating DataFrames vertically. It does not actually modify the DataFrame, it works on a copy and returns the modified copy. You must pass sort = True or sort = False to silence a warning since the default (currently None) is currently deprecated."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# igonre_index will rename the index 0 ... n-1 (default = False)
my_df = pd.append([df1, df2, df...], ignore_index = True, sort = False)

# %%
# append returns a modified copy. It's not inplace
df1.append(df2, sort = True)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrames

# %%
city_loc = pd.DataFrame(
    [
        ["CA", "San Francisco", 37.781334, -122.416728],
        ["NY", "New York", 40.705649, -74.008344],
        ["FL", "Miami", 25.791100, -80.320733],
        ["OH", "Cleveland", 41.473508, -81.739791],
        ["UT", "Salt Lake City", 40.755851, -111.896657]
    ], columns=["state", "city", "lat", "lng"])
city_loc
# Out:
#   state            city        lat         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"])
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %% [markdown]
# ## Append them together

# %%
together = city_loc.append(city_pop, sort = False, ignore_index = True)
together
# Out:
#         state            city        lat         lng  population
# 0          CA   San Francisco  37.781334 -122.416728         NaN
# 1          NY        New York  40.705649  -74.008344         NaN
# 2          FL           Miami  25.791100  -80.320733         NaN
# 3          OH       Cleveland  41.473508  -81.739791         NaN
# 4          UT  Salt Lake City  40.755851 -111.896657         NaN
# 5  California   San Francisco        NaN         NaN    808976.0
# 6    New-York        New York        NaN         NaN   8363710.0
# 7     Florida           Miami        NaN         NaN    413201.0
# 8       Texas         Houston        NaN         NaN   2242193.0

# %% [markdown]
# ---
# title: "Categories (Levels) in a DataFrame"
# description: "Categories (or levels) are categorical variables that usually take on a fixed number of possible values. Examples are sex, blood type, political affiliation etc. Pandas makes it easy to deal with these types of values."
# tags: Pandas, Data Cleaning / Preprocessing
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# make a new column from codes (ex: levels are 0, 1, 2)
df['new_col'] = df['levels'].astype('category')
df['new_col'].cat.categories # => array of categories/levels

# %%
# rename the categories for readability
df['new_col'].cat.categories = ['name_1', 'name_2', 'name_3']

# %% [markdown]
# # Example&

# %% [markdown]
# ## Example DataFrame with codes/levels

# %%
city_eco = pd.DataFrame(
    [
        [808976, "San Francisco", "California", 0],
        [8363710, "New York", "New-York", 0],
        [413201, "Miami", "Florida", 3],
        [2242193, "Houston", "Texas", 7],
    ], columns=["population", "city", "state", "eco_code"])

city_eco
# Out:
#    population           city       state  eco_code
# 0      808976  San Francisco  California         0
# 1     8363710       New York    New-York         0
# 2      413201          Miami     Florida         3
# 3     2242193        Houston       Texas         7

# %% [markdown]
# Right now the `eco_code` column is full of apparently meaningless codes. Let's fix that.

# %% [markdown]
# ## Create a new categorical column based on the `eco_code`s

# %%
city_eco["economy"] = city_eco["eco_code"].astype('category')
city_eco["economy"].cat.categories
# Out:
# Int64Index([0, 3, 7], dtype='int64')

# %% [markdown]
# ## Rename the category with a meaningful name

# %%
city_eco["economy"].cat.categories = ["Finance", "Energy", "Tourism"]
city_eco
# Out:
#    population           city       state  eco_code  economy
# 0      808976  San Francisco  California         0  Finance
# 1     8363710       New York    New-York         0  Finance
# 2      413201          Miami     Florida         3   Energy
# 3     2242193        Houston       Texas         7  Tourism

# %% [markdown]
# **Note:** categorical values are sorted according to their categorical order, *not* their alphabetical (lexicographical) order:

# %%
city_eco.sort_values(by="economy", ascending=False)
# Out:
#    population           city       state  eco_code  economy
# 3     2242193        Houston       Texas         7  Tourism
# 2      413201          Miami     Florida         3   Energy
# 1     8363710       New York    New-York         0  Finance
# 0      808976  San Francisco  California         0  Finance

# %% [markdown]
# ---
# title: "Handling Missing Data: Filling Missing Values (NaNs)"
# description: "Fill all the NaNs in a DataFrame with a particular value."
# tags: Pandas, Data Cleaning / Preprocessing
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# replace all NaN in column with value
df['column'] = df['column'].fillna(value)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
import numpy as np
people_dict = {
    "weight": [68, 83, 112],
    "height": [172, 181, 185],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, np.nan],
    "hobby": ["Biking", "Dancing", "Snowboarding"],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  height  birthyear  children         hobby
# alice        68     172       1985       NaN        Biking
# bob          83     181       1984       3.0       Dancing
# charles     112     185       1992       NaN  Snowboarding

# %% [markdown]
# ## Replace NaNs with 0's

# %%
people['children'] = people['children'].fillna(0)
people
# Out:
#          weight  height  birthyear  children         hobby
# alice        68     172       1985       0.0        Biking
# bob          83     181       1984       3.0       Dancing
# charles     112     185       1992       0.0  Snowboarding

# %% [markdown]
# ---
# title: "Handling Missing Data: Interpolate Missing Values (NaNs)"
# description: "Interpolate missing values (NaNs). Note: DataFrames support only linear interpolation."
# tags: Pandas, Data Cleaning / Preprocessing
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %%
# setting inplace to True changes the orginal df
df['column'].interpolate(inplace = True)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
import numpy as np
people_dict = {
    "weight": [68, 83, 112],
    "height": [172, 181, 185],
    "birthyear": [1985, 1984, 1992],
    "children": [np.nan, 3, np.nan],
    "hobby": ["Biking", "Dancing", "Snowboarding"],
    "order_surveyed": [11, np.nan, 13]
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles"])
people
# Out:
#          weight  height  birthyear  children         hobby  order_surveyed
# alice        68     172       1985       NaN        Biking            11.0
# bob          83     181       1984       3.0       Dancing             NaN
# charles     112     185       1992       NaN  Snowboarding            13.0

# %% [markdown]
# ## Interpolate the missing value

# %%
people['order_surveyed'].interpolate(inplace = True)
people
# Out:
#          weight  height  birthyear  children         hobby  order_surveyed
# alice        68     172       1985       NaN        Biking            11.0
# bob          83     181       1984       3.0       Dancing            12.0
# charles     112     185       1992       NaN  Snowboarding            13.0

# %% [markdown]
# ---
# title: "Handling Missing Data: Drop Rows or Columns with Missing Values (NaNs)"
# description: "Drop a row or a column with missing values (NaNs). Drop a column or row if it has any NaN values or only if it is full of only NaN values."
# tags: Pandas, Data Cleaning / Preprocessing
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import pandas as pd

# %% [markdown]
# - `how = 'any'` (default): if any NA values are present, drop the row or column
# - `how = 'all'`: if all values in the row or column are NA, drop it
# - `inplace = True` (default False): change the original df

# %% [markdown]
# ## Drop Rows

# %%
df.dropna()

# %% [markdown]
# ## Drop Columns

# %%
df.dropna(axis = 1)

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example DataFrame

# %%
import numpy as np
people_dict = {
    "weight": [68, 83, 112, np.nan],
    "height": [172, 181, 185, np.nan],
    "birthyear": [1985, 1984, 1992, np.nan],
    "children": [np.nan, np.nan, np.nan, np.nan],
    "hobby": ["Biking", "Dancing", "Snowboarding", "cash me oustside"],
}
people = pd.DataFrame(people_dict, index=["alice", "bob", "charles", "danielle bregoli"])
people
# Out:
#                   weight  height  birthyear  children             hobby
# alice               68.0   172.0     1985.0       NaN            Biking
# bob                 83.0   181.0     1984.0       NaN           Dancing
# charles            112.0   185.0     1992.0       NaN      Snowboarding
# danielle bregoli     NaN     NaN        NaN       NaN  cash me oustside

# %% [markdown]
# ## Drop Columns

# %%
people.dropna(how = 'all', inplace = True, axis = 1)
people
# Out:
#                   weight  height  birthyear             hobby
# alice               68.0   172.0     1985.0            Biking
# bob                 83.0   181.0     1984.0           Dancing
# charles            112.0   185.0     1992.0      Snowboarding
# danielle bregoli     NaN     NaN        NaN  cash me oustside

# %% [markdown]
# ## Drop Rows

# %%
people = people.dropna()
people
# Out:
#          weight  height  birthyear         hobby
# alice      68.0   172.0     1985.0        Biking
# bob        83.0   181.0     1984.0       Dancing
# charles   112.0   185.0     1992.0  Snowboarding
