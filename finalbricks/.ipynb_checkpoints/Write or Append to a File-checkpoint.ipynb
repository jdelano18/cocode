# %% [markdown]
# ---
# title: "Write or Append to a File"
# description: "Open and write or append to a file."
# tags: Python Fundamentals
# URL: http://ehmatthes.github.io/pcc/cheatsheets/README.html
# Licence:
# Creator:
# Meta: "dont overwrite my file"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Write or Append to a File
#         </h1>
#         <p>Open and write or append to a file.</p>
#     	</div>
# 		</div>

# %% [markdown]
# Passing the ```'w'``` argument to ```open()``` tells Python you want to write to the file. Be careful; this will erase the contents of the file if it already exists. <br> <br> Passing the ```'a'``` argument tells Python you want to append to the end of an existing file.

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# ## Writing to an empty file

# %%
filename = 'journal.txt'
with open(filename, 'w') as f:
    f.write("I love programming!")

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# ## Writing multiple lines to an empty file

# %%
filename = 'journal.txt'
with open(filename, 'w') as f:
    f.write("I love programming!\n")
    f.write("I love creating new games.\n")

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# ## Appending to a file

# %%
filename = 'journal.txt'
with open(filename, 'a') as f:
    f.write("I also love working with data.\n")
    f.write("I love golf and ariana grande too :) \n")
