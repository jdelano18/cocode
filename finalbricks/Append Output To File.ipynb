# %% [markdown]
# ---
# title: "Append Output To File"
# description: "How to append the standard output of a command or program to a file using the Linux command line."
# tags: linux, inputs_and_outputs
# URL: https://github.com/ActiveState/code
# Creator:
# Meta:
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Append Output To File
#         </h1>
#         <p>How to append the standard output of a command or program to a file using the Linux command line.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# <div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
# <span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
# Example
# </span>
# </div>
# </div>

# %% [markdown]
# We can append the outputs of a program to a file by using the `>>` operator.
#
# ## Run `date` To See Standard Output
#
# Note `+"%T.%N"` gives the current time with nanseconds
#
# ```
# date +"%T.%N"
# ```
# ```
# 21:19:26.291589981
# ```
#
# ## Create File
#
# ```
# touch records.txt
# ```
#
# ## Append The Standard Output To File
#
# Note that we run `date +%s%N` four times, each time appending the results to `records.txt`.
#
# ```
# date +"%T.%N" >> records.txt; date +"%T.%N" >> records.txt; date +"%T.%N" >> records.txt; date +"%T.%N"  >> records.txt
# ```
#
# ## View File's Contents To See Redirected Standard Output
#
# ```
# cat records.txt
# ```
# ```
# 21:21:50.875588383
# 21:21:50.876275526
# 21:21:50.876939495
# 21:21:50.877571864
# ```
