# %% [markdown]
# ---
# title: "Basic Math Operators in Python"
# description: "Basic addition, subtraction, multiplication and division in python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "addition adding add subtraction subtract minus times division divide multiplication multiply parentheses"
#
# ---

# %% [markdown]
# # Basic Math Operators

# %% [markdown]
# ## The basic operators are what you would expect:

# %%
1 + 1
# Out:
# 2

# %%
8 - 1
# Out:
# 7

# %%
10 * 2
# Out:
# 20

# %%
# Note: the result of divison is always a float
print(type(35 / 5))
10 / 3
# Out:
# <class 'float'>
# 3.3333333333333335

# %%
# Enforce precedence with parentheses
(1 + 3) * 2
# Out:
# 8
