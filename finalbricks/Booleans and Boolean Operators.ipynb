# %% [markdown]
# ---
# title: "Booleans and Boolean Operators"
# description: "using booleans in python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "True False bool not"
#
# ---

# %% [markdown]
# # Booleans and Boolean Operators

# %% [markdown]
# ## Boolean values are primitives (Note: the capitalization)

# %%
True
False

# %% [markdown]
# ## Negate a boolean with ```not```

# %%
not True   # => False
not False  # => True

# %% [markdown]
# ## Boolean Operators

# %%
# Note "and" and "or" are case-sensitive
True and False  # => False
False or True   # => True

# %% [markdown]
# ## True and False are actually 1 and 0 but with different keywords

# %%
True + True # => 2
True * 8 # => 8
False - 5 # => -5

# %% [markdown]
# ## Comparison operators look at the numerical value of True and False

# %%
0 == False  # => True
1 == True   # => True
2 == True   # => False
-5 != False # => True

# %% [markdown]
# ## Casting Booleans for Evaluation

# %% [markdown]
# Using boolean logical operators on ints casts them to booleans for evaluation, but their non-cast value is returned. Don't mix up with ```bool(ints)``` and bitwise ```and```/```or``` (&,|)

# %%
bool(0)     # => False
bool(4)     # => True
bool(-6)    # => True
0 and 2     # => 0
-5 or 0     # => -5

# %%
# None, 0, and empty strings/lists/dicts/tuples all evaluate to False.
# All other values are True
bool(None)   # => False
bool("")  # => False
bool([])  # => False
bool({})  # => False
bool(())  # => False
