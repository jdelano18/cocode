# %% [markdown]
# ---
# title: "Capture Stack Trace"
# description: "The logging module also allows you to capture the full stack traces in an application. Exception information can be captured if the `exc_info` parameter is True."
# tags: Logging
# URL: https://realpython.com/python-logging/
# Licence:
# Creator:
# Meta: "logging"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Capture Stack Trace
#         </h1>
#         <p>The logging module also allows you to capture the full stack traces in an application. Exception information can be captured if the `exc_info` parameter is True.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# <div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
# <span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
# Key Code
# </span>
# </div>
# </div>

# %%
import logging

# %%
try:
    a = 100 / 0
except Exception as e:
    logging.error("Exception occurred", exc_info=True)
# Out:
# ERROR:root:Exception occurred
# Traceback (most recent call last):
#   File "<ipython-input-3-de5dbd4164d1>", line 2, in <module>
#     a = 100 / 0
# ZeroDivisionError: division by zero
