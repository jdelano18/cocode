# %% [markdown]
# ---
# title: "Check for Existance of Keys in a Dictionary"
# description: "Check if a variable is in the keys in a dictionary."
# tags: Python Fundamentals, Dictionaries
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Check for Existance of Keys in a Dictionary
#         </h1>
#         <p>Check if a variable is in the keys in a dictionary.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
if key in dictionary:
    print("its there")
else:
    print("its not there")

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
d = {'a' : 1, 'b' : 2, 'c' : 3, 'd' : 4, 'e' : 5}
print("a" in d)
print(1 in d)
# Out:
# True
# False
