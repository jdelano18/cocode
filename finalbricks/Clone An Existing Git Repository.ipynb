# %% [markdown]
# ---
# title: "Clone An Existing Git Repository"
# description: "Cloning is the process of pulling down a copy of a repository stored on a server. Go to the parent folder of where you want to repository's folder to be in, then run git clone."
# tags: GIT, Bash
# URL: https://github.com/chrisalbon/notes/
# Licence:
# Creator:
# Meta: "initialize"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Clone An Existing Git Repository
#         </h1>
#         <p>Cloning is the process of pulling down a copy of a repository stored on a server. Go to the parent folder of where you want to repository's folder to be in, then run git clone.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# <div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
# <span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
# Key Code
# </span>
# </div>
# </div>

# %%
# %%bash
# cd ~/Documents
# git clone [url to repository] [name of folder / repository you want]
