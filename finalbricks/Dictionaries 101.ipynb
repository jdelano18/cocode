# %% [markdown]
# ---
# title: "Dictionaries 101"
# description: "dictionary basics in python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "keys and values in dictionary dict lookup get unpack adding to dictionary"
#
# ---

# %% [markdown]
# # Sets

# %% [markdown]
# Sets store ... well sets. Thesee are unordered and unindexed collections without any repeats.

# %%
empty_set = set()
some_set = {1, 1, 2, 2, 3, 4}
some_set
# Out:
# {1, 2, 3, 4}

# %%
# Similar to keys of a dictionary, elements of a set have to be immutable.
invalid_set = {[1], 1}  # => Raises a TypeError: unhashable type: 'list'
valid_set = {(1,), 1}

# %% [markdown]
# ## Adding to a set

# %%
some_set.add(5)  # filled_set is now {1, 2, 3, 4, 5}
some_set.add(5)  # it remains as before {1, 2, 3, 4, 5}

# %% [markdown]
# ## Set Operations

# %% [markdown]
# ### Set intersection with ```&```

# %%
other_set = {3, 4, 5, 6}
print(some_set & other_set)
# Out:
# {3, 4, 5}

# %% [markdown]
# ### Set union with ```|```

# %%
some_set | other_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ### Set difference with ```-```

# %%
{1, 2, 3, 4} - {2, 3, 5}
# Out:
# {1, 4}

# %% [markdown]
# ### Set symmetric difference with ```^```

# %%
{1, 2, 3, 4} ^ {2, 3, 5}
# Out:
# {1, 4, 5}

# %% [markdown]
# ### Check if set on the left is a superset of set on the right

# %%
{1, 2} >= {1, 2, 3}
# Out:
# False

# %% [markdown]
# ### Check if set on the left is a subset of set on the right

# %%
{1, 2} <= {1, 2, 3}
# Out:
# True

# %% [markdown]
# ### Check for existence in a set with ```in```

# %%
print(2 in some_set)   
print(10 in some_set)
# Out:
# True
# False
