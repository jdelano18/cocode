# %% [markdown]
# ---
# title: "Difference Between Sorted and Sort"
# description: "The list.sort() method modifies the original list in-place, whereas the sorted(list) will create a new list in sorted order and leave the original untouched."
# tags: Python Fundamentals, Lists
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "sorted(list) vs. list.sort()"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Difference Between Sorted and Sort
#         </h1>
#         <p>The list.sort() method modifies the original list in-place, whereas the sorted(list) will create a new list in sorted order and leave the original untouched.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
my_list = [5,2,3,4,1]

# %%
sorted_list = sorted(my_list)
print(sorted_list)
print(my_list)
# Out:
# [1, 2, 3, 4, 5]
# [5, 2, 3, 4, 1]

# %%
my_list.sort()
print(my_list)
# Out:
# [1, 2, 3, 4, 5]
