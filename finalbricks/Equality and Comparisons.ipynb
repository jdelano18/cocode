# %% [markdown]
# ---
# title: "Equality and Comparisons"
# description: "using is, ==, <, and > in python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "greater than less than comparing two values. difference between is and =="
#
# ---

# %% [markdown]
# # Equality and Comparisons

# %% [markdown]
# ## Equality is ```==```

# %%
1 == 1  # => True
2 == 1  # => False

# %% [markdown]
# ## Inequality is ```!=```

# %%
1 != 1  # => False
2 != 1  # => True

# %% [markdown]
# ## Other Useful Comparisons

# %%
1 < 10  # => True
1 > 10  # => False
2 <= 2  # => True
2 >= 2  # => True

# %% [markdown]
# ## Combining and Chaining Comparisons

# %%
# Seeing whether a value is in a range
1 < 2 and 2 < 3  # => True
2 < 3 and 3 < 2  # => False

# %%
# Chaining makes this look nicer
1 < 2 < 3  # => True
2 < 3 < 2  # => False

# %% [markdown]
# ## Difference between ```is``` and ```==```

# %% [markdown]
# ```is``` checks if two variables refer to the same object, but ```==``` checks if the objects pointed to have the same values

# %% [markdown]
# ### Example

# %%
a = [1, 2, 3, 4]  
b = a             # Point b at what a is pointing to
b is a            # => True, a and b refer to the same object
b == a            # => True, a's and b's objects are equal

# %%
b = [1, 2, 3, 4]  # Point b at a new list, [1, 2, 3, 4]
b is a            # => False, a and b do not refer to the same object
b == a            # => True, a's and b's objects are equal
