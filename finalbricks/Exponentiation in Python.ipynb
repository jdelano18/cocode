# %% [markdown]
# ---
# title: "Exponentiation in Python"
# description: "exponents in python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "exponents exponentiation raise to the power of"
#
# ---

# %% [markdown]
# # Exponentiation

# %%
2**4
# Out:
# 16
