# %% [markdown]
# ---
# title: "Find The Version Of Git"
# description: "Find the version of git that's running on your computer"
# tags: GIT, Bash
# URL: https://github.com/chrisalbon/notes/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Find The Version Of Git
#         </h1>
#         <p>Find the version of git that's running on your computer</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# <div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
# <span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
# Key Code
# </span>
# </div>
# </div>

# %%
# %%bash
# git --version
# Out:
# git version 2.21.0 (Apple Git-120)
