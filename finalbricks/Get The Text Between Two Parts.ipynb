# %% [markdown]
# ---
# title: "Get The Text Between Two Parts"
# description: "Get the text between two parts. Location of the text can be regular, toend, or tostart."
# tags: Python: Other
# URL: https://github.com/Richienb/quilt
# Licence: Apache License 2.0
# Creator:
# Meta: "indexing"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Get The Text Between Two Parts
#         </h1>
#         <p>Get the text between two parts. Location of the text can be regular, toend, or tostart.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
def textbetween(variable, 
                firstnum=None, 
                secondnum=None,
                locationoftext='regular'):
    """
    Get The Text Between Two Parts
    """
    if locationoftext == 'regular':
        return variable[firstnum:secondnum]
    elif locationoftext == 'toend':
        return variable[firstnum:]
    elif locationoftext == 'tostart':
        return variable[:secondnum]
