# %% [markdown]
# ---
# title: "Get the minimum year allowed by the current OS"
# description: "Get the minimum year allowed by the current OS with the datetime module."
# tags: Datetime
# URL: https://github.com/Richienb/quilt
# Licence: Apache License 2.0
# Creator:
# Meta: "minyear"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Get the minimum year allowed by the current OS
#         </h1>
#         <p>Get the minimum year allowed by the current OS with the datetime module.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
import datetime
import time
def minyear():
    """
    Get the minimum year allowed by the current OS.
    """

    return datetime.MINYEAR
