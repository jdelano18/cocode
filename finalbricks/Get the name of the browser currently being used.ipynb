# %% [markdown]
# ---
# title: "Get the name of the browser currently being used"
# description: "Get the name of the browser currently being used with the webbrowser module."
# tags: Python: Other
# URL: https://github.com/Richienb/quilt
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Get the name of the browser currently being used
#         </h1>
#         <p>Get the name of the browser currently being used with the webbrowser module.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
import webbrowser
def getbrowser():
    """
    Get the name of the browser currently being used
    """

    # Try to find the browser
    try:
        # Get the browser name
        webbrowser.get(using=None)

    # Catch an error
    except RuntimeError:
        # Return nothing
        return None
