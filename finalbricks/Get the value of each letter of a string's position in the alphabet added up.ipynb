# %% [markdown]
# ---
# title: "Add the value of each letter of a string's position in the alphabet"
# description: "Get the value of each letter of a string's position in the alphabet added up."
# tags: Python: Other
# URL: https://github.com/Richienb/quilt
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Add the value of each letter of a string's position in the alphabet
#         </h1>
#         <p>Get the value of each letter of a string's position in the alphabet added up.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
def wordvalue(word):
    """
    Get the value of each letter of a string's position in the alphabet added up

    :type word: string
    :param word: The word to find the value of
    """

    # Set total to 0
    total = 0

    # For each character of word
    for i in enumerate(word):
        # Add it's letter value to total
        total += letternum(word[i[0]])

    # Return the final value
    return total
