# %% [markdown]
# ---
# title: "Headers in Markdown"
# description: "Make different sized headings in Markdown"
# tags: Markdown
# URL:
# Licence:
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Headers in Markdown
#         </h1>
#         <p>Make different sized headings in Markdown</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# Use the hashtag followed by a blank space to add a header (# ). The more hashtags you add before the line will reduce the size of the font.

# %% [markdown]
# `# Title` <br>
# `## Major heading` <br>
# `### Subheadings` <br>
# `### 4th level sub heading`
