# %% [markdown]
# ---
# title: "Import a Module"
# description: "Modules are just ordinary python files containing functions. Learn how to import public modules and your own modules."
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Import a Module
#         </h1>
#         <p>Modules are just ordinary python files containing functions. Learn how to import public modules and your own modules.</p>
#     	</div>
# 		</div>

# %% [markdown]
# You can ```import``` modules in python. Modules are just ordinary Python files. You can write your own and import them. The name of the module is the same as the name of the file. Just make sure your file is in the same folder/directory as your current script or notebook.

# %% [markdown]
# You can import a specific function from a module or you can import all functions from a module. You can also shorten module names.

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# ## Import a specific function from a module

# %%
from math import ceil, floor
print(ceil(3.7))
print(floor(3.7))
# Out:
# 4
# 3

# %% [markdown]
# ## Import all functions from a module

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# ## Shorten module names

# %%
import math as m
math.sqrt(16) == m.sqrt(16)
# Out:
# True

# %% [markdown]
# ## You can find out which functions and attributes are defined in a module.

# %%
import math
dir(math)
