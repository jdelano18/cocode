# %% [markdown]
# ---
# title: "Integer Division Operator"
# description: "How to divide without a remainder using the integer division operator."
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "rounding division"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Integer Division Operator
#         </h1>
#         <p>How to divide without a remainder using the integer division operator.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
# integer division rounds down for positive and negative numbers
5 // 3
# Out:
# 1

# %%
-5.0 // 3.0
# Out:
# -2.0
