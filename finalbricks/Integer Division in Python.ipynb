# %% [markdown]
# ---
# title: "Integer Division in Python"
# description: "using the integer division operator"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "division divide"
#
# ---

# %% [markdown]
# # Integer Division

# %% [markdown]
# ## Integer division ```//``` rounds down for both positive and negative numbers.

# %%
5 // 3
# Out:
# 1

# %%
-5 // 3
# Out:
# -2

# %%
5.0 // 3.0
# Out:
# 1.0

# %%
-5.0 // 3.0
# Out:
# -2.0
