# %% [markdown]
# ---
# title: "List Comprehensions"
# description: "Create new lists in a more concise and elegany way."
# tags: Python Fundamentals, List Comprehensions
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	List Comprehensions
#         </h1>
#         <p>Create new lists in a more concise and elegany way.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
new_list = [value for value in iterable if one_or_more_condition]

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
above_5 = [x for x in [3, 4, 5, 6, 7] if x > 5]
above_5
# Out:
# [6, 7]

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
squares = [i*i for i in range(10)]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
