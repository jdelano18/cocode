# %% [markdown]
# ---
# title: "Listing Files In Bash"
# description: "Listing files in a directory in bash. Learn how to see all files in a directory, see hidden files, more info, and recursively."
# tags: Bash
# URL: https://github.com/kickstartcoding/cheatsheets/blob/master/kickstart-backend/2-bash-git.md
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Listing Files In Bash
#         </h1>
#         <p>Listing files in a directory in bash. Learn how to see all files in a directory, see hidden files, more info, and recursively.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# ls        # List files
# ls -a     # See hidden
# ls -l     # See more info
# ls -R     # Recursive

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# ls
# Out:
# anotherfolder
# dir2
# dir3
# hi.py
# my_notebook.ipynb
# there.ipynb

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# ls -a
# Out:
# .
# ..
# .ipynb_checkpoints
# anotherfolder
# dir2
# dir3
# hi.py
# my_notebook.ipynb
# there.ipynb

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# ls -l
# Out:
# total 16
# drwxr-xr-x  3 jimmydelano  staff   96 Jun 13 11:47 anotherfolder
# drwxr-xr-x  3 jimmydelano  staff   96 Jun 13 11:47 dir2
# drwxr-xr-x  4 jimmydelano  staff  128 Jun 13 11:54 dir3
# -rw-r--r--  1 jimmydelano  staff   20 Jun 13 11:42 hi.py
# -rw-r--r--  1 jimmydelano  staff    6 Jun 13 11:43 there.ipynb

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# ls -R
# Out:
# anotherfolder
# dir2
# dir3
# hi.py
# my_notebook.ipynb
# there.ipynb
#
# ./anotherfolder:
# surprise.txt
#
# ./dir2:
# more.txt
#
# ./dir3:
# files.txt
