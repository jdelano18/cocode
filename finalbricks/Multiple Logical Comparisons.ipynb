# %% [markdown]
# ---
# title: "Multiple Logical Comparisons"
# description: "How to evaluate multiple comparisons in one line using using keywords (is, ==, <, >, and, or)."
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "comparing two values"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Multiple Logical Comparisons
#         </h1>
#         <p>How to evaluate multiple comparisons in one line using using keywords (is, ==, <, >, and, or).</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
# Seeing whether a value is in a range
1 < 2 <= 3   # => True

# %%
# use parenthesees to chain multiple comparisons together
('i' in 'hi' and 'low' in 'hello') or 3 is 3  # => True
