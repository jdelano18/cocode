# %% [markdown]
# ---
# title: "Navigating In Bash"
# description: "Basic navigation commands in bash. Learn how to go in and out of different directories and see which directory you are in at any given time."
# tags: Bash
# URL: https://github.com/kickstartcoding/cheatsheets/blob/master/kickstart-backend/2-bash-git.md
# Licence: Apache License 2.0
# Creator:
# Meta: "cd go up one level"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Navigating In Bash
#         </h1>
#         <p>Basic navigation commands in bash. Learn how to go in and out of different directories and see which directory you are in at any given time.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd name_of_directory
# cd ..     # Go up one
# cd ~      # Go to home
# pwd       # Where am I?

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~
# pwd
# Out:
# /Users/jimmydelano

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# pwd
# cd ..
# pwd
# cd ../Downloads/
# pwd
# Out:
# /Users/jimmydelano/Desktop/myfolder
# /Users/jimmydelano/Desktop
# /Users/jimmydelano/Downloads
