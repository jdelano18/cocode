# %% [markdown]
# ---
# title: "Read Data From A File In Bash"
# description: "Learn how to read data from a file in bash."
# tags: Bash
# URL: https://github.com/kickstartcoding/cheatsheets/blob/master/kickstart-backend/2-bash-git.md
# Licence: Apache License 2.0
# Creator:
# Meta: "cat"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Read Data From A File In Bash
#         </h1>
#         <p>Learn how to read data from a file in bash.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cat filename.txt
# cat file1 file2 file3

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# cat test.txt
# Out:
# this is my example text file with some words

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
# %%bash
# cd ~/Desktop/myfolder
# cat test.txt test2.txt
# Out:
# this is my example text file with some words
# this is another file with some more stuff
