# %% [markdown]
# ---
# title: "Replacing Values In A Pandas DataFrame"
# description: "How to replacing certian values with other values in a pandas dataframe"
# tags: Pandas, Data Cleaning / Preprocessing, Regex, Text Processing
# URL: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# Licence:
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Replacing Values In A Pandas DataFrame
#         </h1>
#         <p>How to replacing certian values with other values in a pandas dataframe</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
# first argument is to_replace and second argument is the value to replace with
df.replace(-999, np.nan)
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 0      Jason    Miller   42           NaN            2.0
# 1      Molly  Jacobson   52           NaN            2.0
# 2       Tina       Ali   36           NaN            NaN
# 3       Jake    Milner   24           2.0            2.0
# 4        Amy     Cooze   73           1.0            NaN

# %% [markdown]
# ---

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create dataframe

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
        'age': [42, 52, 36, 24, 73], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
df
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 0      Jason    Miller   42          -999              2
# 1      Molly  Jacobson   52          -999              2
# 2       Tina       Ali   36          -999           -999
# 3       Jake    Milner   24             2              2
# 4        Amy     Cooze   73             1           -999

# %% [markdown]
# ## Replace all values of -999 with NAN

# %%
df.replace(-999, np.nan)
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 0      Jason    Miller   42           NaN            2.0
# 1      Molly  Jacobson   52           NaN            2.0
# 2       Tina       Ali   36           NaN            NaN
# 3       Jake    Milner   24           2.0            2.0
# 4        Amy     Cooze   73           1.0            NaN

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Learn More
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# Learn more about other parameters in the documentation here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
