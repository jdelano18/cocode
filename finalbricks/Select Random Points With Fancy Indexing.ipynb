# %% [markdown]
# ---
# title: "Select Random Points With Fancy Indexing"
# description: "Fancy indexing is commonly used for selecting a subset of rows from a matrix. We can randomly select n points and visualize the results. This approach can be used to partition datasets and create test/train splits."
# tags: Numpy, Matplotlib
# URL: https://github.com/jakevdp/PythonDataScienceHandbook/
# Licence: MIT for code, Text is copyrighted
# Creator:
# Meta: "visualize subset of array"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Select Random Points With Fancy Indexing
#         </h1>
#         <p>Fancy indexing is commonly used for selecting a subset of rows from a matrix. We can randomly select n points and visualize the results. This approach can be used to partition datasets and create test/train splits.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # for plot styling

# %%
mean = [0, 0]
cov = [[1, 2],
       [2, 5]]
X = rand.multivariate_normal(mean, cov, 100)
X.shape
# Out:
# (100, 2)

# %%
plt.scatter(X[:, 0], X[:, 1]);

# %%
# let's select 20 random incides
indices = np.random.choice(X.shape[0], 20, replace=False)
indices
# Out:
# array([39,  8, 17, 66, 53, 92, 74, 84, 12, 63, 18, 59, 41, 49, 42, 94, 98,
#        23,  7, 55])

# %%
# use fancy indexing to get the points
selection = X[indices]  # fancy indexing here
selection.shape
# Out:
# (20, 2)

# %%
# fill in the random points we got
plt.scatter(X[:, 0], X[:, 1], alpha=0.3)
plt.scatter(selection[:, 0], selection[:, 1],
            facecolor='black', s=15);
