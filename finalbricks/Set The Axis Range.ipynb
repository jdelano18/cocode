# %% [markdown]
# ---
# title: "Set The Axis Range"
# description: "Restrict or expand the bounds of the axis range with the axis function from Matplotlib. Change the bounds for both the x and y axis or just one of them."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "xlim ylim axis change"
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Set The Axis Range
#         </h1>
#         <p>Restrict or expand the bounds of the axis range with the axis function from Matplotlib. Change the bounds for both the x and y axis or just one of them.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
import matplotlib.pyplot as plt

# %%
# change x and y axis bounds at once
plt.axis([xmin, xmax, ymin, ymax])

# %%
# change x-axis bounds
plt.xlim(bottom, top)

# %%
# change y-axis bounds
plt.ylim(bottom, top)

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.axis([-4, 6, 0, 7])
plt.show()

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.ylim(1, 10) 
plt.xlim(-10,4)
plt.show()
