# %% [markdown]
# ---
# title: "Set Union Operation"
# description: "Calculating the union of multiple sets with the set union operation."
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Set Union Operation
#         </h1>
#         <p>Calculating the union of multiple sets with the set union operation.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
some_set | other_set | another_one...

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
primes = {2,3,5,7,11,13}
odds = {1,3,5,7,9,11,13,15}
pow2 = {2,4,8,16}
primes | odds | pow2
# Out:
# {1, 2, 3, 4, 5, 7, 8, 9, 11, 13, 15, 16}
