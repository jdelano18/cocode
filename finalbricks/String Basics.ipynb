# %% [markdown]
# ---
# title: "String Basics"
# description: "strings 101 for python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "length of a string. add strings. concatenate strings. index a string"
#
# ---

# %% [markdown]
# # String Basics

# %% [markdown]
# ## Strings are created with ```"```s or ```'```s

# %%
"This is a string."
'This is also a string.'

# %% [markdown]
# ## Strings can be added (or concatenated)

# %%
"Hello " + "world!"  # => "Hello world!"

# String literals (but not variables) can be concatenated without using '+'
"Hello " "world!"    # => "Hello world!"

# %% [markdown]
# ## Strings can be treated like a list of characters and indexed

# %%
"This is a string"[0]
# Out:
# 'T'

# %% [markdown]
# ## Length of a String

# %%
len("This is a string")
# Out:
# 16
