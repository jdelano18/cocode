# %% [markdown]
# ---
# title: "String format f strings"
# description: "f strings and format function"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: "f string. format function"
#
# ---

# %% [markdown]
# # String Format / F Strings

# %% [markdown]
# ## Use the ```.format``` function to format strings like this:

# %%
"{} can be {}".format("Strings", "interpolated")
# Out:
# 'Strings can be interpolated'

# %%
# You can repeat the formatting arguments to save some typing.
"{0} be nimble, {0} be quick, {0} jump over the {1}".format("Jack", "candle stick")
# Out:
# 'Jack be nimble, Jack be quick, Jack jump over the candle stick'

# %%
# You can use keywords if you don't want to count.
"{name} likes to eat {food}".format(name="Jimmy", food="pie")
# Out:
# 'Jimmy likes to eat pie'

# %% [markdown]
# ## Use f-strings or formateed string literals in Python 3.6+

# %%
name = "Tim"
f"{name} has great hair."
# Out:
# 'Tim has great hair.'

# %%
# You can basically put any Python statement inside the braces and it will be output in the string.
f"{name} is {len(name)} characters long."
# Out:
# 'Tim is 3 characters long.'
