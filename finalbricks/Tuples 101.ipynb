# %% [markdown]
# ---
# title: "Tuples 101"
# description: "basics with tuples in python"
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Tuples

# %% [markdown]
# ## Tuples are like lists, but tuples are immutable

# %%
tup = (1, 2, 3)
tup[0]
# tup.append(4)   -- you can't do this!
# tup[0] = 7      -- you can't do this either!
# Out:
# 1

# %% [markdown]
# ## Tuples of length 1

# %%
# Note that a tuple of length one has to have a comma after the last element but
# tuples of other lengths, even zero, do not.
print(type((1)))  
print(type((1,)))  
print(type(()))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# ## Many list operations work on tuples too

# %%
print(len(tup))         
print(tup + (4, 5, 6))  
print(tup[:2])        
print(2 in tup)
# Out:
# 3
# (1, 2, 3, 4, 5, 6)
# (1, 2)
# True

# %% [markdown]
# ## Unpacking Tuples

# %%
# You can unpack tuples (or lists) into variables
a, b, c = (1, 2, 3)  # a is now 1, b is now 2 and c is now 3

# %%
# You can also do extended unpacking
a, *b, c = (1, 2, 3, 4)  # a is now 1, b is now [2, 3] and c is now 4

# %%
# Tuples are created by default if you leave out the parentheses
d, e, f = 4, 5, 6  # tuple 4, 5, 6 is unpacked into variables d, e and f
# respectively such that d = 4, e = 5 and f = 6

# %%
# Now look how easy it is to swap two values
e, d = d, e  # d is now 5 and e is now 4
