# %% [markdown]
# ---
# title: "Arithmetic Operations For Arrays"
# description: "The usual arithmetic operators for numpy's ndarrays. Note: the operators apply elementwise and the multiplication is NOT matrix multiplication."
# tags: Python Fundamentals
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Arithmetic Operations For Arrays
#         </h1>
#         <p>The usual arithmetic operators for numpy's ndarrays. Note: the operators apply elementwise and the multiplication is NOT matrix multiplication.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# All the usual arithmetic operators (`+`, `-`, `*`, `/`, `//`, `**`, etc.) can be used with `ndarray`s. They apply *elementwise*:

# %%
a = np.array([14, 23, 32, 41])
b = np.array([5,  4,  3,  2])
print("a + b  =", a + b)
print("a - b  =", a - b)
print("a * b  =", a * b)
print("a / b  =", a / b)
print("a // b  =", a // b)
print("a % b  =", a % b)
print("a ** b =", a ** b)
# Out:
# a + b  = [19 27 35 43]
# a - b  = [ 9 19 29 39]
# a * b  = [70 92 96 82]
# a / b  = [  2.8          5.75        10.66666667  20.5       ]
# a // b  = [ 2  5 10 20]
# a % b  = [4 3 2 1]
# a ** b = [537824 279841  32768   1681]

# %% [markdown]
# The arrays must have the same shape. If they do not, NumPy will apply the *broadcasting rules*. Search for NumPy's broadcasting rules for more information.
