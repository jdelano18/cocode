# %% [markdown]
# ---
# title: "Combine Arrays With Different Data Types"
# description: "When trying to combine arrays with different dtypes, NumPy will upcast to a type capable of handling all possible values (regardless of what the actual values are)."
# tags: Python Fundamentals
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Combine Arrays With Different Data Types
#         </h1>
#         <p>When trying to combine arrays with different dtypes, NumPy will upcast to a type capable of handling all possible values (regardless of what the actual values are).</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
k1 = np.arange(0, 5, dtype=np.uint8)
print(k1.dtype, k1)
# Out:
# uint8 [0 1 2 3 4]

# %%
k2 = k1 + np.array([5, 6, 7, 8, 9], dtype=np.int8)
print(k2.dtype, k2)
# Out:
# int16 [ 5  7  9 11 13]

# %% [markdown]
# Note that `int16` is required to represent all *possible* `int8` and `uint8` values (from -128 to 255), even though in this case a uint8 would have sufficed.

# %%
k3 = k1 + 1.5
print(k3.dtype, k3)
# Out:
# float64 [ 1.5  2.5  3.5  4.5  5.5]
