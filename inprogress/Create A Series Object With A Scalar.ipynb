# %% [markdown]
# ---
# title: "Create A Series Object With A Scalar"
# description: "Initialize a Series object using a scalar and a list of index labels such that all rows have the same value."
# tags: Pandas
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Create A Series Object With A Scalar
#         </h1>
#         <p>Initialize a Series object using a scalar and a list of index labels such that all rows have the same value.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
import pandas as pd

# %%
# all rows will have the scalar as their value
s = pd.Series(scalar, list_of_index_labels)

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Example
#     	</span>
# 		</div>
# 		</div>

# %%
meaning = pd.Series(42, ["life", "universe", "everything"])
meaning
# Out:
# life          42
# universe      42
# everything    42
# dtype: int64
