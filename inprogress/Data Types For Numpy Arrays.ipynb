# %% [markdown]
# ---
# title: "Data Types For Numpy Arrays"
# description: "NumPy's ndarrays are efficient in part because all their elements must have the same type (usually numbers). Learn about the different dtypes for ndarrays."
# tags: Python Fundamentals
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Data Types For Numpy Arrays
#         </h1>
#         <p>NumPy's ndarrays are efficient in part because all their elements must have the same type (usually numbers). Learn about the different dtypes for ndarrays.</p>
#     	</div>
# 		</div>

# %% [markdown]
# ## You can check what the data type is by looking at the `dtype` attribute:

# %%
c = np.arange(1, 5)
print(c.dtype, c)
# Out:
# int64 [1 2 3 4]

# %%
c = np.arange(1.0, 5.0)
print(c.dtype, c)
# Out:
# float64 [ 1.  2.  3.  4.]

# %% [markdown]
# ## Instead of letting NumPy guess what data type to use, you can set it explicitly when creating an array by setting the `dtype` parameter:

# %%
d = np.arange(1, 5, dtype=np.complex64)
print(d.dtype, d)
# Out:
# complex64 [ 1.+0.j  2.+0.j  3.+0.j  4.+0.j]

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Learn More
#     	</span>
# 		</div>
# 		</div>

# %% [markdown]
# Available data types include `int8`, `int16`, `int32`, `int64`, `uint8`|`16`|`32`|`64`, `float16`|`32`|`64` and `complex64`|`128`. Check out [the documentation](http://docs.scipy.org/doc/numpy-1.10.1/user/basics.types.html) for the full list.
