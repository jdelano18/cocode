# %% [markdown]
# ---
# title: "Error Handling: The Try-Except Block"
# description: "When you think an error may occur, you can write a try-except block to handle the exception that might be raised. Understand how to use this try-except block."
# tags: Python Fundamentals, Error Handling
# URL: http://ehmatthes.github.io/pcc/cheatsheets/README.html
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# The ```try``` block lets you test a block of code for errors.

# %% [markdown]
# The ```except``` block lets you handle the error

# %% [markdown]
# # Example&

# %%
try:
    print(5/0)
except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %% [markdown]
# # Example&

# %%
f_name = 'journal.txt'
try:
    with open(f_name) as f_obj:
        lines = f_obj.readlines()
except FileNotFoundError:
    msg = f"Can't find file {f_name}."
    print(msg)
# Out:
# Can't find file journal.txt.
