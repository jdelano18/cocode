# %% [markdown]
# ---
# title: "Flip the names and keys in a dictionary"
# description: "This is a simple function from Quilt Lang, a Python library that allows you write less code to do more things."
# tags:
# URL: https://github.com/Richienb/quilt
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
#  <div>
#     	<img src="./coco.png" style="float: left;height: 55px">
#     	<div style="height: 150px;text-align: center; padding-top:5px">
#         <h1>
#       	Flip the names and keys in a dictionary
#         </h1>
#         <p>This is a simple function from Quilt Lang, a Python library that allows you write less code to do more things.</p>
#     	</div>
# 		</div>

# %% [markdown]
#  <div style="height:40px">
# 		<div style="width:100%; text-align:center; border-bottom: 1px solid #000; line-height:0.1em; margin:40px 0 20px;">
#     	<span style="background:#fff; padding:0 10px; font-size:25px; font-family: 'Open Sans', sans-serif;">
#         Key Code
#     	</span>
# 		</div>
# 		</div>

# %%
def dictflip(dictionary):
    """
    Flip the names and keys in a dictionary.

    This means that this:
    {'key1': 'value1', 'key2': 'value2'}
    will be converted into this:
    {'value1': 'key1', 'value2': 'key2'}

    :type dictionary: dictionary
    :param dictionary: The dictionary to flip.
    """

    return {v: k for k, v in dictionary.items()}
