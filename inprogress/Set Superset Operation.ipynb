# %% [markdown]
# ---
# title: "Set Superset Operation"
# description: "Calculating if one set is a superset of another set with the set superset operation in python."
# tags: Python Fundamentals
# URL: https://learnxinyminutes.com/docs/python3/
# Licence:
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
# see if some_set is a superset of some other_set
some_set >= other_set

# %% [markdown]
# # Example&

# %%
{1, 2} >= {1, 2, 3}
# Out:
# False

# %%
{1, 2, 3} >= {1, 2}
# Out:
# True
