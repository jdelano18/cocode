# %% [markdown]
# ---
# title: "Difference Between Pylab, Pyplot, and Matplotlib"
# description: "Pylab vs. Pyplot vs. Matplotlib."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "vs"
#
# ---

# %% [markdown]
# There is some confusion around the relationship between pylab, pyplot and matplotlib.
#
# **matplotlib** is the full library, it contains everything including pylab and pyplot.
#
# **Pyplot** provides a number of tools to plot graphs, including the state-machine interface to the underlying object-oriented plotting library.
#
# **Pylab** is a convenience module that imports matplotlib.pyplot and NumPy in a single name space. You will find many examples using pylab, but it is no longer recommended (because *explicit* imports are better than *implicit* ones).

# %% [markdown]
# ---
# title: "Plot A List of Coordinates"
# description: "Plotting in Matplotlib is as simple as calling the `plot` function with some data, and then calling the `show` function!If the `plot` function is given one array of data, it will use it as the coordinates on the vertical axis, and it will just use each data point's index in the array as the horizontal coordinate. You can also provide two arrays: one for the horizontal axis `x`, and the second for the vertical axis `y`."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 4, 9, 5, 3])
plt.show()

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.show()

# %% [markdown]
# ---
# title: "Set The Axis Range"
# description: "Restrict or expand the bounds of the axis range with the axis function from Matplotlib. Change the bounds for both the x and y axis or just one of them."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "xlim ylim axis change"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
# change x and y axis bounds at once
plt.axis([xmin, xmax, ymin, ymax])

# %%
# change x-axis bounds
plt.xlim(bottom, top)

# %%
# change y-axis bounds
plt.ylim(bottom, top)

# %% [markdown]
# # Example&

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.axis([-4, 6, 0, 7])
plt.show()

# %% [markdown]
# # Example&

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.ylim(1, 10) 
plt.xlim(-10,4)
plt.show()

# %% [markdown]
# ---
# title: "Add Axis Labels"
# description: "Add an axis label to the x or y axis of a matplotlib plot."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "matplotlib pyplot plot"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
# x-axis label
plt.xlabel("x_axis_label")

# %%
# y-axis label
plt.ylabel("y_axis_label")

# %% [markdown]
# # Example&

# %% [markdown]
# ## Create example mathematical function

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2

# %% [markdown]
# ## Plot it

# %%
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y = x^2")
plt.show()

# %% [markdown]
# ---
# title: "Add A Title"
# description: "Add a title to your graph in matplotlib."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "matplotlib pyplot plot"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Your_title")

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2

# %%
plt.plot(x, y)
plt.title("Square function")
plt.show()

# %% [markdown]
# ---
# title: "Add A Grid Background"
# description: "Add a grid in the background of your matplotlib plot."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "matplotlib pyplot plot"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.grid(True)

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2

# %%
plt.plot(x, y)
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Change The Style Or Color Of Points And Lines"
# description: "By default, matplotlib draws a blue line between consecutive points. You can pass a 3rd argument to change the line's style and color. For example `g--` means "green dashed line". You can plot multiple lines on one graph very simply: just pass x1, y1, style1, x2, y2, style2, ... "
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "dashed line style and color red green blue"
#
# ---

# %% [markdown]
# # Key Code

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Check out [the documentation](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot) for the full list of style & color options.

# %%
# replace style with your desired color/style
plt.plot(x, y, 'style')

# %% [markdown]
# # Example&

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100], [0, 0, 100, 100, 0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# # Example&

# %%
plt.plot([0, 100, 100, 0, 0], [0, 0, 100, 100, 0], "r^")
plt.plot([0, 100, 50, 0, 100], [0, 100, 130, 100, 0], "b:")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# # Learn More&

# %% [markdown]
# The plot function returns a list of `Line2D` objects (one for each line).  You can set extra attributes on these lines, such as the line width, the dash style or the alpha level.  See the full list of attributes in [the documentation](http://matplotlib.org/users/pyplot_tutorial.html#controlling-line-properties).

# %%
x = np.linspace(-1.4, 1.4, 30)
line1, line2, line3 = plt.plot(x, x, 'g--', x, x**2, 'r:', x, x**3, 'b^')
line1.set_linewidth(3.0)
line1.set_dash_capstyle("round")
line3.set_alpha(0.2)
plt.show()

# %% [markdown]
# ---
# title: "Save A Matplotlib Figure"
# description: "Saving a figure to disk is as simple as calling matplotlib's savefig method with the name of the file (or a file object). The available image formats depend on the graphics backend you use."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.savefig('filename.png')

# %% [markdown]
# # Example&

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.plot(x, x**2)
plt.savefig("my_square_function.png")

# %% [markdown]
# ---
# title: "Create A Grid Of Subplots"
# description: "A matplotlib figure may contain multiple subplots. These subplots are organized in a grid. To create a subplot, just call the subplot function, and specify the number of rows and columns in the figure, and the index of the subplot you want to draw on (starting from 1, then left to right, and top to bottom). Note: pyplot keeps track of the currently active subplot (which you can get a reference to by calling plt.gca()), so when you call the plot function, it draws on the active subplot."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
# 1 row, 2 columns, 1st subplot = left
plt.subplot(1, 2, 1)
plt.plot(x, y)

# 1 row, 2 columns, 2nd subplot = right
plt.subplot(1, 2, 2)
plt.plot(y, x)

# %% [markdown]
# # Example&

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x)
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2)
plt.subplot(2, 2, 3)  # 2 rows, 2 columns, 3rd subplot = bottow left
plt.plot(x, x**3)
plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot = bottom right
plt.plot(x, x**4)
plt.show()

# %% [markdown]
# * Note that `subplot(223)` is a shorthand for `subplot(2, 2, 3)`.

# %% [markdown]
# It is easy to create subplots that span across multiple grid cells like so:

# %%
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x)
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2)
plt.subplot(2, 1, 2)  # 2 rows, *1* column, 2nd subplot = bottom
plt.plot(x, x**3)
plt.show()

# %% [markdown]
# # Example&

# %% [markdown]
# If you need more complex subplot positioning, you can use `subplot2grid` instead of `subplot`. You specify the number of rows and columns in the grid, then your subplot's position in that grid (top-left = (0,0)), and optionally how many rows and/or columns it spans.

# %%
plt.subplot2grid((3,3), (0, 0), rowspan=2, colspan=2)
plt.plot(x, x**2)
plt.subplot2grid((3,3), (0, 2))
plt.plot(x, x**3)
plt.subplot2grid((3,3), (1, 2), rowspan=2)
plt.plot(x, x**4)
plt.subplot2grid((3,3), (2, 0), colspan=2)
plt.plot(x, x**5)
plt.show()

# %% [markdown]
# # Learn More&

# %% [markdown]
# If you need even more flexibility in subplot positioning, check out the [GridSpec documentation](http://matplotlib.org/users/gridspec.html)

# %% [markdown]
# ---
# title: "Create Multiple Figures"
# description: "By default, matplotlib creates figure(1) automatically. When you switch figure, pyplot keeps track of the currently active figure (which you can get a reference to by calling plt.gcf()), and the active subplot of that figure becomes the current subplot."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "many graphs"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
# switch to figure n
plt.figure(n)
plt.plot(...)

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(-1.4, 1.4, 30)

plt.figure(1)
plt.subplot(211)
plt.plot(x, x**2)
plt.title("Square and Cube")
plt.subplot(212)
plt.plot(x, x**3)

plt.figure(2, figsize=(10, 5))
plt.subplot(121)
plt.plot(x, x**4)
plt.title("y = x**4")
plt.subplot(122)
plt.plot(x, x**5)
plt.title("y = x**5")

plt.figure(1)      # back to figure 1, current subplot is 212 (bottom)
plt.plot(x, -x**3, "r:")

plt.show()

# %% [markdown]
# ---
# title: "Add Text On Top of Graph"
# description: " You can call `text` to add/draw text at any location in the graph. Just specify the horizontal and vertical coordinates and the text, and optionally some extra attributes."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "draw text horizontal vertical alignment bounding box bbox annotate"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
# only a few of the possible arguments
plt.text(x, y, "my text", fontsize=10, color='blue', 
         ha="center", weight='heavy')

# %% [markdown]
# **Note:** `ha` is an alias for `horizontalalignment`

# %% [markdown]
# For more text properties, visit [the documentation](http://matplotlib.org/users/text_props.html#text-properties).

# %% [markdown]
# # Example&

# %%
x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px**2

plt.plot(x, x**2, "b-", px, py, "ro")

plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='blue', horizontalalignment="center")
plt.text(px - 0.08, py, "Beautiful point", ha="right", weight="heavy")
plt.text(px, py, "x = %0.2f\ny = %0.2f"%(px, py), rotation=50, color='gray')

plt.show()

# %% [markdown]
# # Example&

# %% [markdown]
# It is quite frequent to annotate elements of a graph, such as the beautiful point above. The `annotate` function makes this easy: just indicate the location of the point of interest, and the position of the text, plus optionally some extra attributes for the text and the arrow.

# %%
plt.plot(x, x**2, px, py, "ro")
plt.annotate("Beautiful point", xy=(px, py), xytext=(px-1.3,py+0.5),
                           color="green", weight="heavy", fontsize=14,
                           arrowprops={"facecolor": "lightgreen"})
plt.show()

# %% [markdown]
# # Example&

# %% [markdown]
# You can also add a bounding box around your text by using the `bbox` attribute:

# %%
plt.plot(x, x**2, px, py, "ro")

bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
plt.text(px-0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=5)
plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='black', ha="center", bbox=bbox_props)

plt.show()

# %% [markdown]
# # Example&

# %% [markdown]
# Just for fun, if you want an [xkcd](http://xkcd.com)-style plot, just draw within a `with plt.xkcd()` section:

# %%
with plt.xkcd():
    plt.plot(x, x**2, px, py, "ro")

    bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
    plt.text(px-0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

    bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=5)
    plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='black', ha="center", bbox=bbox_props)

    plt.show()

# %% [markdown]
# # Learn More&

# %% [markdown]
#  Any text in matplotlib may contain TeX equation expressions, see [the documentation](http://matplotlib.org/users/mathtext.html) for more details.

# %% [markdown]
# ---
# title: "Legends"
# description: "The simplest way to add a legend is to set a label on all lines, then just call the `legend` function."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.legend(loc='location')

# %% [markdown]
# The location could be something like 'upper right' or 'lower left'. The string 'best' places the legend at the location with the minimum overlap with other stuff. This option can be quite slow for plots with large amounts of data -- instead, you may find faster performance by providing a specific location.

# %% [markdown]
# See more in [the documentation](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.legend.html)

# %% [markdown]
# # Example

# %%
x = np.linspace(-1.4, 1.4, 50)
plt.plot(x, x**2, "r--", label="Square function")
plt.plot(x, x**3, "g-", label="Cube function")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Log Scale for Y-Axis"
# description: "Matplotlib supports non linear scales. Set the yscale as logarithmic instead of linear (default)."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.yscale('log')

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(0.1, 15, 500)
y = x**3/np.exp(2*x)

plt.figure(2)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Logit Scale for Y-Axis"
# description: "Matplotlib supports non linear scales. Set the yscale as logit instead of linear (default)."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.yscale('logit')

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(0.1, 15, 500)
y = x**3/np.exp(2*x)

plt.figure(3)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Symlog Scale for Y-Axis"
# description: "Matplotlib supports non linear scales. Set the yscale as symmetrical log instead of linear (default)."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "symmetrical log"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
plt.yscale('symlog', linthreshy=0.05)

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(0.1, 15, 500)
y = x**3/np.exp(2*x)

plt.figure(4)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.05)
plt.title('symlog')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Add Ticks Or Tick Lines"
# description: "The axes have little marks called "ticks". To be precise, "ticks" are the locations of the marks (eg. (-1, 0, 1)), "tick lines" are the small lines drawn at those locations, "tick labels" are the labels drawn next to the tick lines, and "tickers" are objects that are capable of deciding where to place ticks. The default tickers typically do a pretty good job at placing ~5 to 8 ticks at a reasonable distance from one another."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "tickers. add minor ticks"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax.set_xticks(np.arange(-2, 2, 1))
ax.set_yticks([-2, 0, 1, 2])

# %%
# activate minor ticks
plt.minorticks_on()

# %% [markdown]
# # Example&

# %%
import numpy as np
x = np.linspace(-2, 2, 100)

fig, ax = plt.subplots()
plt.plot(x, x**3)
ax.set_xticks(np.arange(-2, 2, 1))
plt.grid(True)
plt.title("Manual ticks on the x-axis")
plt.show()

# %% [markdown]
# # Example&

# %%
fig, ax = plt.subplots()
plt.plot(x, x**3)
plt.minorticks_on()
ax.set_xticks([-2, 0, 1, 2])
ax.set_yticks(np.arange(-5, 5, 1))
ax.yaxis.set_ticklabels(["min", -4, -3, -2, -1, 0, 1, 2, 3, "max"])
plt.title("Manual ticks and tick labels\n(plus minor ticks) on the y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Polar Projections"
# description: "Drawing a polar graph is as easy as setting the projection attribute of a plot to `'polar'` when creating the subplot."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt

# %%
# 111 = 1x1 grid, 1st subplot
plt.subplot(111, projection='polar')

# %% [markdown]
# # Example&

# %%
import numpy as np
radius = 1
theta = np.linspace(0, 2*np.pi*radius, 1000)

plt.subplot(111, projection='polar')
plt.plot(theta, np.sin(5*theta), "g-")
plt.plot(theta, 0.5*np.cos(20*theta), "b-")
plt.show()

# %% [markdown]
# ---
# title: "Plot 3D Projection"
# description: "You need to import `Axes3D`, which registers the `"3d"` projection. Then create a subplot setting the `projection = "3d"`. This returns an `Axes3DSubplot` object, which you can use to call `plot_surface`, giving x, y, and z coordinates, plus optional attributes."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "3 three dimensions graph contour plot"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z)

# %% [markdown]
# # Example&

# %%
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %% [markdown]
# # Example&

# %% [markdown]
# Another way to display this same data is via a *contour plot*.

# %%
plt.contourf(X, Y, Z, cmap=matplotlib.cm.coolwarm)
plt.colorbar()
plt.show()

# %% [markdown]
# ---
# title: "Add Lines To A Graph"
# description: "You can draw lines using the `plot` function. You can also use the `hlines` and `vlines` functions that plot horizontal and vertical line segments."
# tags: Matplotlib, Visualizations
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: "hlines vlines plot"
#
# ---

# %% [markdown]
# # Key Code&

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# plot horizontal line
plt.hlines(y_value, xmin, xmax)

# %%
# plot vertical line
plt.vlines(x_value, ymin, ymax)

# %%
# plot y = mx + b
x = np.linspace(-5,5,100)
y = m*x + b
plt.plot(x, y)

# %% [markdown]
# # Example&

# %% [markdown]
# It is often convenient to create a utility function that plots a (seemingly) infinite line across the graph, given a slope and an intercept.

# %%
from numpy.random import randn

def plot_line(axis, slope, intercept, **kargs):
    xmin, xmax = axis.get_xlim()
    plt.plot([xmin, xmax], [xmin*slope+intercept, xmax*slope+intercept], **kargs)

x = randn(1000)
y = 0.5*x + 5 + randn(1000)*2
plt.axis([-2.5, 2.5, -5, 15])
plt.scatter(x, y, alpha=0.2)
#plt.plot(1, 0, "ro")
plt.vlines(1, -5, 0, color="red")
plt.hlines(0, -2.5, 1, color="red")
plot_line(axis=plt.gca(), slope=0.5, intercept=5, color="magenta")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# title: "Animations In Matplotlib"
# description: "Although matplotlib is mostly used to generate images, it is also capable of displaying animations, depending on the Backend you use. In a Jupyter notebook, we need to use the `nbagg` backend to use interactive matplotlib features, including animations. We also need to import `matplotlib.animation`."
# tags: Matplotlib
# URL: https://github.com/ageron/handson-ml
# Licence: Apache License 2.0
# Creator:
# Meta: ""
#
# ---

# %% [markdown]
# # Key Code

# %%
# %matplotlib nbagg
import matplotlib.animation as animation

# %%
an = animation.FuncAnimation(fig, 
            function, frames=100)

# %% [markdown]
# # Example&

# %% [markdown]
# In this example, we start by creating data points, then we create an empty plot, we define the update function that will be called at every iteration of the animation, and finally we add an animation to the plot by creating a `FuncAnimation` instance.
#
# The `FuncAnimation` constructor takes a figure, an update function and optional arguments. We specify that we want a 100-frame long animation, with 20ms between each frame. At each iteration, `FuncAnimation` calls our update function and passes it the frame number `num` (from 0 to 99 in our case) followed by the extra arguments that we specified with `fargs`.
#
# Our update function simply sets the line data to be the first `num` data points (so the data gets drawn gradually), and just for fun we also add a small random number to each data point so that the line appears to wiggle.

# %%
x = np.linspace(-1, 1, 100)
y = np.sin(x**2*25)
data = np.array([x, y])

fig = plt.figure()
line, = plt.plot([], [], "r-") # start with an empty plot
plt.axis([-1.1, 1.1, -1.1, 1.1])
plt.plot([-0.5, 0.5], [0, 0], "b-", [0, 0], [-0.5, 0.5], "b-", 0, 0, "ro")
plt.grid(True)
plt.title("Marvelous animation")

# this function will be called at every iteration
def update_line(num, data, line):
    line.set_data(data[..., :num] + np.random.rand(2, num) / 25)  # we only plot the first `num` data points.
    return line,

line_ani = animation.FuncAnimation(fig, update_line, frames=100, fargs=(data, line), interval=67)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
