# %%
import pandas as pd
import sqlite3
import os
import json
import sqlalchemy

# %%
class a_brick:
    __slots__ = ['_idNum', '_title','_desc','_code','_tags']
    
    def __init__ (self, idNum, title, desc, code, tags):
        self._idNum = idNum
        self._title = str(title)
        self._desc = str(desc)
        self._code = str(code)
        self._tags = str(tags)
    
    @property
    def idNum(self):
        return self._idNum
    
    @property
    def title(self):
        return self._title
    
    @property
    def desc(self):
        return self._desc
    
    @property
    def code(self):
        return self._code
    
    @property
    def tags(self):
        return self._tags
    
    @property
    def astuple(self):
        return (self.idNum, self.title, self.desc, self.code, self.tags)

# %%
rootdir = "../finalbricks/"
files = []
output = []

for filename in os.listdir(rootdir):
    if filename.endswith(".ipynb"): 
        files.append(filename)
    else:
        continue

#open each notebook in JSON format
for name in files:
    with open(rootdir+name) as json_file:
        code = json.load(json_file)
        nextfile = ()
        
        for item in code["cells"][0]["source"][1:4]: # we want title, description, and tags only
            item = item.replace('\"','').strip()
            index = item.find(':')
            nextfile += (item[index+2:],)
            
        title, desc, tags = nextfile
        # figure out how to fix the tags later
        brick = a_brick(None, title, desc, code, tags)
        output.append(brick.astuple)

# %%
sqlite_db = './bricks5.sqlite'
conn = sqlite3.connect(sqlite_db) 
c = conn.cursor()

# %%
for o in output:
    c.execute('INSERT INTO bricks5 VALUES (?, ?, ?, ?, ?)', o)

conn.commit()

# %%
df = pd.read_sql('SELECT * FROM bricks5', con=conn)
df
# Out:
#     id                                              title  \
# 0    1               Pandas select rows containing values
# 1    2                                   Pandas Crosstabs
# 2    3  pandas select rows when the column has certain...
# 3    4                   Covert String to Float in Pandas
# 4    5              Converting Prices to Floats in Pandas
# 5    6          Pandas List the Unique Values in a Column
# 6    7                           Pandas Delete Duplicates
# 7    8                          Pandas Find Unique Values
# 8    9                              Pandas Groupy Rows By
# 9   10            Sum The Column of a DataFrame in Pandas
# 10  11             Remove a Given Character from a String
# 11  12                         Replacing Values in Pandas
# 12  13                                   Change Data Type
# 13  14                                 Replace Characters
# 14  15               Pandas select rows containing values
# 15  16                                   Pandas Crosstabs
# 16  17  pandas select rows when the column has certain...
# 17  18                   Covert String to Float in Pandas
# 18  19              Converting Prices to Floats in Pandas
# 19  20          Pandas List the Unique Values in a Column
# 20  21                           Pandas Delete Duplicates
# 21  22                          Pandas Find Unique Values
# 22  23                              Pandas Groupy Rows By
# 23  24            Sum The Column of a DataFrame in Pandas
# 24  25             Remove a Given Character from a String
# 25  26                         Replacing Values in Pandas
# 26  27                                   Change Data Type
# 27  28                                 Replace Characters
#
#                                                  desc  \
# 0                Pandas select rows containing values
# 1                   using the crosstabs method pandas
# 2   pandas select rows when the column has certain...
# 3   Changing the data type from string to float in...
# 4    Turning a column of prices into floats in pandas
# 5           find the unique values in a column pandas
# 6             deleting and dropping duplicates pandas
# 7            Finding unique values in a column pandas
# 8                                    grouby in pandas
# 9                sum the column of a dataframe pandas
# 10                 removing a character from a string
# 11               Replacing values in pandas dataframe
# 12  Changing the data type for value and column in...
# 13                   replacing characters in a string
# 14               Pandas select rows containing values
# 15                  using the crosstabs method pandas
# 16  pandas select rows when the column has certain...
# 17  Changing the data type from string to float in...
# 18   Turning a column of prices into floats in pandas
# 19          find the unique values in a column pandas
# 20            deleting and dropping duplicates pandas
# 21           Finding unique values in a column pandas
# 22                                   grouby in pandas
# 23               sum the column of a dataframe pandas
# 24                 removing a character from a string
# 25               Replacing values in pandas dataframe
# 26  Changing the data type for value and column in...
# 27                   replacing characters in a string
#
#                                                  code  \
# 0   {'cells': [{'cell_type': 'markdown', 'metadata...
# 1   {'cells': [{'cell_type': 'markdown', 'metadata...
# 2   {'cells': [{'cell_type': 'markdown', 'metadata...
# 3   {'cells': [{'cell_type': 'markdown', 'metadata...
# 4   {'cells': [{'cell_type': 'markdown', 'metadata...
# 5   {'cells': [{'cell_type': 'markdown', 'metadata...
# 6   {'cells': [{'cell_type': 'markdown', 'metadata...
# 7   {'cells': [{'cell_type': 'markdown', 'metadata...
# 8   {'cells': [{'cell_type': 'markdown', 'metadata...
# 9   {'cells': [{'cell_type': 'markdown', 'metadata...
# 10  {'cells': [{'cell_type': 'markdown', 'metadata...
# 11  {'cells': [{'cell_type': 'markdown', 'metadata...
# 12  {'cells': [{'cell_type': 'markdown', 'metadata...
# 13  {'cells': [{'cell_type': 'markdown', 'metadata...
# 14  {'cells': [{'cell_type': 'markdown', 'metadata...
# 15  {'cells': [{'cell_type': 'markdown', 'metadata...
# 16  {'cells': [{'cell_type': 'markdown', 'metadata...
# 17  {'cells': [{'cell_type': 'markdown', 'metadata...
# 18  {'cells': [{'cell_type': 'markdown', 'metadata...
# 19  {'cells': [{'cell_type': 'markdown', 'metadata...
# 20  {'cells': [{'cell_type': 'markdown', 'metadata...
# 21  {'cells': [{'cell_type': 'markdown', 'metadata...
# 22  {'cells': [{'cell_type': 'markdown', 'metadata...
# 23  {'cells': [{'cell_type': 'markdown', 'metadata...
# 24  {'cells': [{'cell_type': 'markdown', 'metadata...
# 25  {'cells': [{'cell_type': 'markdown', 'metadata...
# 26  {'cells': [{'cell_type': 'markdown', 'metadata...
# 27  {'cells': [{'cell_type': 'markdown', 'metadata...
#
#                                                  tags
# 0                                         Pandas, EDA
# 1          Pandas, Data Cleaning / Preprocessing, EDA
# 2                                         Pandas, EDA
# 3   Pandas, Data Cleaning / Preprocessing, Text Pr...
# 4   Pandas, Data Cleaning / Preprocessing, Regex, ...
# 5               Pandas, Data Cleaning / Preprocessing
# 6               Pandas, Data Cleaning / Preprocessing
# 7                                         Pandas, EDA
# 8               Pandas, Data Cleaning / Preprocessing
# 9          Pandas, Data Cleaning / Preprocessing, EDA
# 10  Data Cleaning / Preprocessing, Python Fundamen...
# 11  Pandas, Data Cleaning / Preprocessing, Regex, ...
# 12  Pandas, Data Cleaning / Preprocessing, Text Pr...
# 13  Data Cleaning / Preprocessing, Text Processing...
# 14                                        Pandas, EDA
# 15         Pandas, Data Cleaning / Preprocessing, EDA
# 16                                        Pandas, EDA
# 17  Pandas, Data Cleaning / Preprocessing, Text Pr...
# 18  Pandas, Data Cleaning / Preprocessing, Regex, ...
# 19              Pandas, Data Cleaning / Preprocessing
# 20              Pandas, Data Cleaning / Preprocessing
# 21                                        Pandas, EDA
# 22              Pandas, Data Cleaning / Preprocessing
# 23         Pandas, Data Cleaning / Preprocessing, EDA
# 24  Data Cleaning / Preprocessing, Python Fundamen...
# 25  Pandas, Data Cleaning / Preprocessing, Regex, ...
# 26  Pandas, Data Cleaning / Preprocessing, Text Pr...
# 27  Data Cleaning / Preprocessing, Text Processing...
